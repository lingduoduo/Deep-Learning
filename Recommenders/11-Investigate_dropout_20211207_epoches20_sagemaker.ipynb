# %% [markdown]
# ### Setup envs

# %%
import boto3
from sagemaker import get_execution_role

# %%
# !pip install tensorflow==2.5.2
# Out:
# Requirement already satisfied: tensorflow==2.5.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.5.2)
# Requirement already satisfied: gast==0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (0.4.0)
# Requirement already satisfied: termcolor~=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (3.19.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (3.7.4.3)
# Requirement already satisfied: numpy~=1.19.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.19.5)
# Requirement already satisfied: google-pasta~=0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.12.1)
# Requirement already satisfied: grpcio~=1.34.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.34.1)
# Requirement already satisfied: absl-py~=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (0.15.0)
# Requirement already satisfied: tensorboard~=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (2.7.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (2.5.0)
# Requirement already satisfied: h5py~=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (3.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (3.3.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.12)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (0.36.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow==2.5.2) (2.5.0.dev2021032900)
# Requirement already satisfied: cached-property in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow==2.5.2) (1.5.2)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (58.5.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (2.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (2.26.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow==2.5.2) (0.4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.2) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.2) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.2) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.2) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.2) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.2) (3.1.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install tensorflow-recommenders==0.5.2
# Out:
# Requirement already satisfied: tensorflow-recommenders==0.5.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (0.5.2)
# Requirement already satisfied: absl-py>=0.1.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow-recommenders==0.5.2) (0.15.0)
# Requirement already satisfied: tensorflow>=2.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow-recommenders==0.5.2) (2.5.2)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from absl-py>=0.1.6->tensorflow-recommenders==0.5.2) (1.15.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (2.5.0.dev2021032900)
# Requirement already satisfied: grpcio~=1.34.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.34.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.19.1)
# Requirement already satisfied: tensorboard~=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (2.7.0)
# Requirement already satisfied: h5py~=3.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.12.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.7.4.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.12)
# Requirement already satisfied: numpy~=1.19.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.19.5)
# Requirement already satisfied: termcolor~=1.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.1.0)
# Requirement already satisfied: gast==0.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (2.5.0)
# Requirement already satisfied: wheel~=0.35 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (0.36.2)
# Requirement already satisfied: astunparse~=1.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.6.3)
# Requirement already satisfied: cached-property in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (58.5.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.3.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow>=2.3.0->tensorflow-recommenders==0.5.2) (3.1.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
role = get_execution_role()
bucket = "ling-cold-start-data"
prefix = "2021-11-22"
data_key = "2021-11-22.csv"
data_location = "s3://{}/{}/{}".format(bucket, prefix, data_key)

# %%
import os
import logging
import time

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_recommenders as tfrs

# %% [markdown]
# ### Model definition

# %%
class UserModel(tf.keras.Model) :

    def __init__(self, conf):
        super().__init__()

        self.gender_embedding = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.StringLookup(
                vocabulary=conf['unique_genders'], mask_token=None),
            tf.keras.layers.Embedding(len(conf['unique_genders']) + 1, 4),
        ])

        self.lang_embedding = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.StringLookup(
                 vocabulary=conf['unique_langs'], mask_token=None),
            tf.keras.layers.Embedding(len(conf['unique_langs']) + 1, 10),
        ])

        self.country_embedding = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.StringLookup(
                vocabulary=conf['unique_countries'], mask_token=None),
            tf.keras.layers.Embedding(len(conf['unique_countries']) + 1, 10),
        ])

        self.network_embedding = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.StringLookup(
                vocabulary=conf['unique_networks'], mask_token=None),
            tf.keras.layers.Embedding(len(conf['unique_networks']) + 1, 4),
        ])

        age_boundaries = np.array([18, 25, 30, 35, 40, 45, 50, 55, 60, 65, float("inf")])
        self.viewer_age_embedding = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.Discretization(age_boundaries.tolist()),
            tf.keras.layers.Embedding(len(age_boundaries), 2)
        ])

        self.centroids = tf.constant(
            [
                [36.68147669256268, -82.8910274009993],
                [23.22243322909555, 78.23027450833709],
                [50.04997682638993, 0.22379313938744885],
                [37.9309447099281, -117.00741350764692],
                [-32.795864819917725, 148.7159172660312],
                [-18.570548393114084, -54.280255665692565],
                [13.921140442819565, 116.38740315555172],
                [29.78951080730802, 40.279515865947936]]
        )
        self.viewer_lat_long_embedding = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.TextVectorization(
                standardize = None, split = self.classify,
                vocabulary = [str(i) for i in range(len(self.centroids))],
                max_tokens=len(self.centroids) + 2
                ),
            tf.keras.layers.Embedding(len(self.centroids) + 2, 2),
        ])

    @tf.function()
    def call(self, inputs):
        return tf.concat([
            self.gender_embedding(inputs["viewer_gender"]),
            self.lang_embedding(inputs["viewer_lang"]),
            self.country_embedding(inputs["viewer_country"]),
            self.network_embedding(inputs["viewer_network"]),
            self.viewer_age_embedding(inputs["viewer_age"]),
            self.viewer_lat_long_embedding(inputs["viewer_lat_long"]),
        ], axis = 1)

    @tf.keras.utils.register_keras_serializable()
    def classify(self, pair):
        """
        given a datapoint, compute the cluster closest to the datapoint. Return the cluster ID of that cluster.
        :param pair:
        :return: cluster ID
        """
        str_data = tf.strings.split(pair, sep = ",").values
        str_data = tf.map_fn(lambda x: tf.strings.regex_replace(x, "b'", ""), str_data)
        datapoints = tf.map_fn(lambda x: tf.strings.to_number(x), str_data, dtype = (tf.float32))
        datapoints = tf.reshape(datapoints, [-1, 2])

        expanded_centroids = tf.expand_dims(self.centroids, 1)
        expanded_vectors = tf.expand_dims(datapoints, 0)
        distances = tf.reduce_sum(tf.square(tf.subtract(expanded_vectors, expanded_centroids)), 2)
        clusters = tf.math.argmin(distances)
        return tf.strings.as_string(clusters)

# %%
class QueryModel(tf.keras.Model):
	"""Model for encoding user queries."""

	def __init__(self, conf):
		"""Model for encoding user queries.

		Args:
		  layer_sizes:
			A list of integers where the i-th entry represents the number of units
			the i-th layer contains.
		"""
		super().__init__()

		# We first use the user model for generating embeddings.
		self.embedding_model = UserModel(conf)
		self.dense_layers = tf.keras.Sequential(
			[
				tf.keras.layers.Dense(32, activation = 'relu', kernel_regularizer = tf.keras.regularizers.L2(0.0001)),
				tf.keras.layers.Dense(32)
			]
		)

	def call(self, inputs):
		feature_embedding = self.embedding_model(inputs)
		return self.dense_layers(feature_embedding)

# %%
class BroadcasterModel(tf.keras.Model):

    def __init__(self, conf):
        super().__init__()

        self.broadcaster_embedding = tf.keras.Sequential([
            tf.keras.layers.experimental.preprocessing.StringLookup(
                vocabulary=conf['unique_broadcasters'], mask_token=None),
            tf.keras.layers.Embedding(len(conf['unique_broadcasters']) + 1, conf['broadcaster_embedding_dimension'])
        ])

    def call(self, broadcaster):
        return tf.concat([
            self.broadcaster_embedding(broadcaster),
        ], axis=1)

# %%
class CandidateModel(tf.keras.Model):
	"""Model for encoding movies."""

	def __init__(self, conf):
		"""Model for encoding movies.
	
		Args:
		  layer_sizes:
			A list of integers where the i-th entry represents the number of units
			the i-th layer contains.
		"""
		super().__init__()

		self.embedding_model = BroadcasterModel(conf)
            
		self.dense_layers = tf.keras.Sequential(
			[
				tf.keras.layers.Dense(32, activation = 'relu', kernel_regularizer = tf.keras.regularizers.L2(0.0001)),
				tf.keras.layers.Dropout(0.5),
				tf.keras.layers.Dense(32)
			]
		)   

	def call(self, inputs):
		feature_embedding = self.embedding_model(inputs)
		return self.dense_layers(feature_embedding)

# %% [markdown]
# ### Load data

# %%
def load_data_file_cold(file, stats):
    print('loading file:' + file)
    training_df = pd.read_csv(
        file,
        skiprows=[0],
        names=["viewer",
               "broadcaster",
               "viewer_age",
               "viewer_gender",
               "viewer_longitude",
               "viewer_latitude",
               "viewer_lang",
               "viewer_country",
               "broadcaster_age",
               "broadcaster_gender",
               "broadcaster_longitude",
               "broadcaster_latitude",
               "broadcaster_lang",
               "broadcaster_country",
               "duration", 
               "viewer_network", 
               "broadcaster_network", 
               "viewer_lat_long_cluster",
               "rank"], 
        dtype={
            'viewer': np.unicode,
            'broadcaster': np.unicode,
            'viewer_age': np.single,
            'viewer_gender': np.unicode,
            'viewer_longitude': np.single,
            'viewer_latitude': np.single,
            'viewer_lang': np.unicode,
            'viewer_country': np.unicode,
            'broadcaster_age': np.single,
            'broadcaster_longitude': np.single,
            'broadcaster_latitude': np.single,
            'broadcaster_lang': np.unicode,
            'broadcaster_country': np.unicode,
            'viewer_network': np.unicode,
            'broadcaster_network': np.unicode,
            'viewer_lat_long_cluster': np.unicode,
            'rank': np.unicode,
        })

    values = {
        'viewer': 'unknown',
        'broadcaster': 'unknown',
        'viewer_age': 30,
        'viewer_gender': 'unknown',
        'viewer_longitude': 0,
        'viewer_latitude': 0,
        'viewer_lang': 'unknown',
        'viewer_country': 'unknown',
        'broadcaster_age': 30,
        'broadcaster_longitude': 0,
        'broadcaster_latitude': 0,
        'broadcaster_lang': 'unknown',
        'broadcaster_country': 'unknown',
        'duration': 0,
        'viewer_network': 'unknown',
        'broadcaster_network': 'unknown',
        "viewer_lat_long": tf.constant(["40.36393,-74.89611"]),
        'rank': '1'
    }
    training_df.fillna(value=values, inplace=True)
    training_df['viewer_lat_long'] = training_df[['viewer_latitude', 'viewer_longitude']].apply(lambda x: '{},{}'.format(x[0],x[1]), axis=1)
    print(training_df.head(10))
    print(training_df.iloc[-10:])
    # stats.send_stats('data-size', len(training_df.index))
    return training_df


def load_training_data_cold(file, stats):
    ratings_df = load_data_file_cold(file, stats)
    print('creating data set')
    training_ds = (
        tf.data.Dataset.from_tensor_slices(
            ({
                "viewer": tf.cast(
                    ratings_df['viewer'].values,
                    tf.string),
                "viewer_gender": tf.cast(
                    ratings_df['viewer_gender'].values,
                    tf.string),
                "viewer_lang": tf.cast(
                    ratings_df['viewer_lang'].values,
                    tf.string),
                "viewer_country": tf.cast(
                    ratings_df['viewer_country'].values,
                    tf.string),
                "viewer_age": tf.cast(
                    ratings_df['viewer_age'].values,
                    tf.int32),
                "viewer_longitude": tf.cast(
                    ratings_df['viewer_longitude'].values,
                    tf.float16),
                "viewer_latitude": tf.cast(
                    ratings_df['viewer_latitude'].values,
                    tf.float16),
                "broadcaster": tf.cast(
                    ratings_df['broadcaster'].values,
                    tf.string),
                "viewer_network": tf.cast(
                    ratings_df['viewer_network'].values,
                    tf.string),
                "broadcaster_network": tf.cast(
                    ratings_df['broadcaster_network'].values,
                    tf.string),
                "viewer_lat_long": tf.cast(
                    ratings_df['viewer_lat_long'].values,
                    tf.string),
            })))

    return training_ds

def prepare_training_data_cold(train_ds):
    print('prepare_training_data')
    training_ds = train_ds.cache().map(lambda x: {
        "broadcaster": x["broadcaster"],
        "viewer": x["viewer"],
        "viewer_gender": x["viewer_gender"],
        "viewer_lang": x["viewer_lang"],
        "viewer_country": x["viewer_country"],
        "viewer_age": x["viewer_age"],
        "viewer_longitude": x["viewer_longitude"],
        "viewer_latitude": x["viewer_latitude"],
        "viewer_network": x["viewer_network"],
        "broadcaster_network": x["broadcaster_network"],
        "viewer_lat_long": x["viewer_lat_long"],
    }, num_parallel_calls=tf.data.AUTOTUNE,
       deterministic=False)

    print('done prepare_training_data')
    return training_ds

# %%
def get_broadcaster_data_set(train_ds):
    broadcasters = train_ds.cache().map(lambda x: x["broadcaster"], num_parallel_calls=tf.data.AUTOTUNE, deterministic=False)
    broadcasters_ds = tf.data.Dataset.from_tensor_slices(
        np.unique(list(broadcasters.as_numpy_iterator())))
    return broadcasters_ds

# %%
training_dataset = load_training_data_cold(file=data_location, stats="")
# Out:
# loading file:s3://ling-cold-start-data/2021-11-22/2021-11-22.csv
#                                             viewer  \
# 0  45 85 43 06 5f e1 cc 1d ad 2b 95 55 59 7f e1 4b
# 1  9d 41 ac 98 8b 54 6f 78 50 d4 db 0b d8 fd 80 df
# 2  12 02 e1 9b a4 23 af d1 c5 c1 aa d0 05 fa 51 cf
# 3  c8 d8 15 6e cf 5b 09 e3 d6 f3 16 9e 9c 05 40 d8
# 4  9d 41 ac 98 8b 54 6f 78 50 d4 db 0b d8 fd 80 df
# 5  88 3a 7b 32 40 44 eb 66 03 93 e2 93 3b ba 21 14
# 6  d4 e6 67 39 64 40 e5 59 93 2b c2 b8 50 de 26 03
# 7  e5 98 43 d1 4e 13 aa 68 c7 ba a4 9e 5f 5c 3b 3e
# 8  09 10 8b df fb 46 9f 7e c2 93 97 5d 8c 05 72 2c
# 9  c8 d8 15 6e cf 5b 09 e3 d6 f3 16 9e 9c 05 40 d8
#
#                                        broadcaster  viewer_age viewer_gender  \
# 0  f2 4c 75 ee 7b 35 16 8e db 23 23 62 95 5f e0 d5        26.0          male
# 1  88 10 58 1a cf b1 b8 8a 86 92 2e bf 6d 29 6d 30        29.0          male
# 2  fd 87 40 b6 5b 39 1f 24 80 bd 9c 37 06 d0 27 74        30.0          male
# 3  10 f0 80 30 38 2f 14 08 4c 96 56 c7 cb 49 66 76        38.0          male
# 4  e7 d4 20 80 b2 4d c0 03 51 cf 74 f2 0f 4d 2a b7        29.0          male
# 5  8f 81 bf 37 c7 f8 bb 39 05 6d f6 ac 98 40 90 96        31.0          male
# 6  5a a2 44 eb 15 e0 6e 7b cd a2 bc a7 f7 e4 e1 6f        28.0        female
# 7  b9 77 c6 1b 2f be 5f ef 36 eb 50 bf c7 5c be f8        39.0        female
# 8  54 83 12 73 cc 9e 9d e8 5c 14 66 a2 23 f3 f9 9d        56.0          male
# 9  29 dc d6 72 f0 61 f4 ab fd d2 4c 6c 89 fc 64 e6        38.0          male
#
#    viewer_longitude  viewer_latitude viewer_lang viewer_country  \
# 0        -84.509697        40.405102          en             US
# 1        -83.509697        40.405102          en             US
# 2        -83.509697        39.405102          es             US
# 3        -84.509697        40.405102          en             US
# 4        -83.509697        39.405102          en             US
# 5        -83.509697        39.405102          en             US
# 6        -83.509697        39.405102          en             US
# 7        -83.509697        40.405102          en             US
# 8        -83.509697        40.405102          en             US
# 9        -83.509697        40.405102          en             US
#
#    broadcaster_age broadcaster_gender  broadcaster_longitude  \
# 0             29.0             female             -82.868401
# 1             34.0             female             -93.788399
# 2             33.0             female             -83.038002
# 3             36.0             female             -80.133598
# 4             33.0             female             -72.994499
# 5             24.0             female             -83.043900
# 6             24.0               male             -81.525002
# 7             20.0               male             -79.023003
# 8             29.0             female             -82.000000
# 9             31.0             female             -95.626099
#
#    broadcaster_latitude broadcaster_lang broadcaster_country  duration  \
# 0             44.581699               en                  US        44
# 1             29.301201               en                  US       111
# 2             37.755699               en                  US        97
# 3             27.235800               en                  US        20
# 4             41.752102               en                  US       120
# 5             40.987202               en                  US        30
# 6             39.222000               en                  US        14
# 7             35.426800               en                  US       212
# 8             40.965099               en                  US        64
# 9             32.815899               en                  US        14
#
#   viewer_network broadcaster_network viewer_lat_long_cluster rank  \
# 0         meetme              meetme                       0    1
# 1         meetme              meetme                       0    1
# 2         meetme              meetme                       0    1
# 3         meetme              meetme                       0    1
# 4         meetme              meetme                       0    1
# 5         meetme              meetme                       0    1
# 6         meetme               skout                       0    1
# 7         meetme              meetme                       0    1
# 8         meetme              meetme                       0    1
# 9         meetme              meetme                       0    1
#
#                         viewer_lat_long
# 0  40.40510177612305,-84.50969696044922
# 1  40.40510177612305,-83.50969696044922
# 2  39.40510177612305,-83.50969696044922
# 3  40.40510177612305,-84.50969696044922
# 4  39.40510177612305,-83.50969696044922
# 5  39.40510177612305,-83.50969696044922
# 6  39.40510177612305,-83.50969696044922
# 7  40.40510177612305,-83.50969696044922
# 8  40.40510177612305,-83.50969696044922
# 9  40.40510177612305,-83.50969696044922
#                                                    viewer  \
# 10797660  ad c1 92 2d 08 f0 26 dc 10 3d 4f 94 6b b5 5f bc
# 10797661  11 77 33 4d e4 25 4f 1c b4 d9 91 2a e9 a0 6a bf
# 10797662  92 80 ae ec c2 ab e0 9d 06 cf 7d 1a 1c c1 92 f0
# 10797663  f1 e2 4c 73 68 58 bd 55 3f a6 0f 13 31 a2 55 9b
# 10797664  bf 7a 80 73 a4 4e 06 af 99 17 0a 8b ff 99 79 73
# 10797665  b0 00 56 e8 6c 7d af 38 12 20 d2 e9 cb e3 0e 96
# 10797666  70 20 3a f0 cb 9f 27 8e 9d 88 36 e3 49 8c 8c 66
# 10797667  00 0c 90 5f 02 a0 c4 41 ea ce 4f d3 84 9d 90 c0
# 10797668  39 ec 3a 32 fd 29 05 84 ea b5 01 9f bd fe d7 cd
# 10797669  3a ad bd 73 88 43 10 c4 8d f7 5a bc b3 7d 0f 46
#
#                                               broadcaster  viewer_age  \
# 10797660  f8 e6 f5 e8 16 d8 9f ad f6 40 d5 22 67 aa e7 8c        34.0
# 10797661  54 e2 20 d5 c9 9a 8c 71 e5 04 1f 13 de ea 37 a9        34.0
# 10797662  d1 12 72 c8 9d d7 fe f4 ea 0d 46 17 14 24 be a9        29.0
# 10797663  e6 52 19 01 5b 0c 8b 51 45 24 aa 0d 4f ba 42 68        40.0
# 10797664  42 a6 c2 c2 d4 9b b8 04 56 4f 7c de 6c 19 57 26        36.0
# 10797665  81 9b 35 89 2b 5c eb f1 73 ea 3b 23 3f 8c 58 50        34.0
# 10797666  08 be d8 51 05 57 32 b8 19 95 f6 ff 31 25 20 c4        22.0
# 10797667  4f da 0d cc 91 d8 d2 23 aa 7e 59 f7 77 8f d1 d5        38.0
# 10797668  95 9d e8 05 4e 2b ba 0c 95 66 8d 61 43 87 dc 74        29.0
# 10797669  84 02 0a d7 8a a9 3e 9a e0 19 23 dd 88 79 f9 55        29.0
#
#          viewer_gender  viewer_longitude  viewer_latitude viewer_lang  \
# 10797660        female        -88.699997        41.200001          en
# 10797661          male       -104.043999        40.740002          en
# 10797662          male       -119.112000        36.380001          en
# 10797663          male         31.018000        31.281000          en
# 10797664          male         -9.500000        52.700001          en
# 10797665          male        -94.473000        40.082001          en
# 10797666          male        -40.268002       -19.156000          pt
# 10797667          male         51.146000        27.412001          en
# 10797668          male       -120.394997        39.618999          en
# 10797669          male         46.882999        25.547001          en
#
#          viewer_country  broadcaster_age broadcaster_gender  \
# 10797660             US             40.0               male
# 10797661             US             35.0             female
# 10797662             US             23.0             female
# 10797663             SA             20.0             female
# 10797664             US             29.0             female
# 10797665             US             24.0             female
# 10797666             BR             18.0               male
# 10797667             SA             29.0               male
# 10797668             US             24.0             female
# 10797669             SA             27.0             female
#
#           broadcaster_longitude  broadcaster_latitude broadcaster_lang  \
# 10797660               1.000000              1.000000               en
# 10797661            -104.015099             39.767300               en
# 10797662            -118.932701             36.388500               en
# 10797663              35.833000             34.833000               en
# 10797664              -7.480000             51.916000               en
# 10797665             123.591003              7.944000               en
# 10797666             -37.622299             -3.876000               pt
# 10797667              47.673000             25.750000               en
# 10797668            -120.466003             39.575901               en
# 10797669              47.726501             25.641701               en
#
#          broadcaster_country  duration viewer_network broadcaster_network  \
# 10797660                  US        20            pof                 pof
# 10797661                  US        17          skout              meetme
# 10797662                  US        37          skout              meetme
# 10797663                  LB        18          skout               skout
# 10797664                  IE        31            pof               skout
# 10797665                  PH       143          skout               skout
# 10797666                  BR       200          skout              meetme
# 10797667                  SA       116          skout               skout
# 10797668                  US       246          skout              meetme
# 10797669                  SA        13          skout              meetme
#
#          viewer_lat_long_cluster rank                         viewer_lat_long
# 10797660                       0    1    41.20000076293945,-88.69999694824219
# 10797661                       3    1    40.7400016784668,-104.04399871826172
# 10797662                       3    1  36.380001068115234,-119.11199951171875
# 10797663                       7    1      31.2810001373291,31.01799964904785
# 10797664                       2    1                  52.70000076293945,-9.5
# 10797665                       0    1    40.082000732421875,-94.4729995727539
# 10797666                       5    1   -19.1560001373291,-40.268001556396484
# 10797667                       7    1    27.41200065612793,51.145999908447266
# 10797668                       3    1    39.61899948120117,-120.3949966430664
# 10797669                       7    1   25.547000885009766,46.882999420166016
# creating data set

# %%
train = prepare_training_data_cold(training_dataset)
# Out:
# prepare_training_data
# done prepare_training_data

# %%
broadcasters_data_set = get_broadcaster_data_set(training_dataset)

# %% [markdown]
# ### Prepare model conf

# %%
def get_list(training_data, key):
    return training_data.batch(1_000_000).map(lambda x: x[key], num_parallel_calls=tf.data.AUTOTUNE, deterministic=False)


def get_unique_list(data):
    return np.unique(np.concatenate(list(data)))

# %%
user_genders = get_list(train, 'viewer_gender')

# %%
user_langs = get_list(train, 'viewer_lang')

# %%
user_countries = get_list(train, 'viewer_country')

# %%
viewer_age = get_list(train, 'viewer_age')

# %%
user_networks = get_list(train, 'viewer_network')

# %% [markdown]
# ### derive input dims

# %%
unique_user_genders = get_unique_list(user_genders)

# %%
len(unique_user_genders)
# Out:
# 2

# %%
unique_user_langs = get_unique_list(user_langs)

# %%
len(unique_user_langs)
# Out:
# 68

# %%
unique_user_countries = get_unique_list(user_countries)

# %%
len(unique_user_countries)
# Out:
# 208

# %%
unique_user_networks = get_unique_list(user_networks)

# %%
len(unique_user_networks)
# Out:
# 4

# %%
broadcaster_ids = get_list(train, 'broadcaster')

# %%
unique_broadcasters = get_unique_list(broadcaster_ids)

# %%
len(unique_broadcasters)
# Out:
# 123683

# %%
broadcaster_embedding_dimension = 32

# %%
cold_start_conf = {
    'unique_genders': unique_user_genders,
    'unique_langs': unique_user_langs,
    'unique_countries': unique_user_countries,
    'unique_networks': unique_user_networks,
    'unique_broadcasters': unique_broadcasters,
    'broadcaster_embedding_dimension': broadcaster_embedding_dimension
}

# %%
cold_start_conf
# Out:
# {'unique_genders': array([b'female', b'male'], dtype=object),
#  'unique_langs': array([b'af', b'ar', b'az', b'bg', b'bn', b'bs', b'ca', b'cs', b'da',
#         b'de', b'el', b'en', b'es', b'eu', b'fa', b'fi', b'fr', b'gl',
#         b'gu', b'he', b'hi', b'hr', b'hu', b'hy', b'id', b'in', b'it',
#         b'iw', b'ja', b'ka', b'km', b'ko', b'ks', b'lo', b'lt', b'lv',
#         b'mk', b'ml', b'mr', b'ms', b'my', b'nb', b'ne', b'nl', b'pa',
#         b'pl', b'ps', b'pt', b'ro', b'ru', b'si', b'sk', b'sl', b'sq',
#         b'sr', b'sv', b'sw', b'ta', b'te', b'th', b'to', b'tr', b'uk',
#         b'ur', b'uz', b'vi', b'yo', b'zh'], dtype=object),
#  'unique_countries': array([b'150', b'419', b'AC', b'AD', b'AE', b'AF', b'AG', b'AI', b'AL',
#         b'AM', b'AO', b'AQ', b'AR', b'AS', b'AT', b'AU', b'AW', b'AX',
#         b'AZ', b'BA', b'BB', b'BD', b'BE', b'BF', b'BG', b'BH', b'BI',
#         b'BJ', b'BN', b'BO', b'BQ', b'BR', b'BS', b'BW', b'BY', b'BZ',
#         b'CA', b'CC', b'CF', b'CH', b'CI', b'CL', b'CM', b'CN', b'CO',
#         b'CR', b'CU', b'CV', b'CW', b'CY', b'CZ', b'DE', b'DK', b'DM',
#         b'DO', b'DZ', b'EA', b'EC', b'EE', b'EG', b'EH', b'EN', b'ER',
#         b'ES', b'ET', b'FI', b'FJ', b'FM', b'FR', b'GB', b'GE', b'GF',
#         b'GH', b'GI', b'GL', b'GM', b'GN', b'GP', b'GR', b'GT', b'GU',
#         b'GY', b'HK', b'HN', b'HR', b'HT', b'HU', b'IC', b'ID', b'IE',
#         b'IL', b'IM', b'IN', b'IO', b'IQ', b'IR', b'IS', b'IT', b'JE',
#         b'JM', b'JO', b'JP', b'KE', b'KG', b'KH', b'KN', b'KR', b'KW',
#         b'KY', b'KZ', b'LA', b'LB', b'LI', b'LK', b'LT', b'LU', b'LV',
#         b'LY', b'MA', b'MC', b'MD', b'ME', b'MG', b'MK', b'MM', b'MN',
#         b'MO', b'MP', b'MR', b'MU', b'MV', b'MX', b'MY', b'MZ', b'NG',
#         b'NI', b'NL', b'NO', b'NP', b'NZ', b'OM', b'PA', b'PE', b'PH',
#         b'PK', b'PL', b'PM', b'PR', b'PS', b'PT', b'PW', b'PY', b'QA',
#         b'RE', b'RO', b'RS', b'RU', b'SA', b'SC', b'SD', b'SE', b'SG',
#         b'SH', b'SI', b'SK', b'SL', b'SM', b'SN', b'SO', b'SS', b'ST',
#         b'SV', b'SX', b'SY', b'SZ', b'TC', b'TD', b'TG', b'TH', b'TL',
#         b'TM', b'TN', b'TR', b'TT', b'TW', b'TZ', b'UA', b'UG', b'UK',
#         b'UM', b'US', b'UY', b'UZ', b'VE', b'VG', b'VI', b'VN', b'VU',
#         b'WF', b'WS', b'XK', b'XL', b'YE', b'ZA', b'ZG', b'ZM', b'ZW',
#         b'unknown'], dtype=object),
#  'unique_networks': array([b'meetme', b'pof', b'skout', b'zoosk'], dtype=object),
#  'unique_broadcasters': array([b'00 00 20 da f6 46 b2 f6 dc 17 2f 29 f6 94 e0 3a',
#         b'00 00 57 d7 03 6d 73 83 3e 58 ec 06 39 87 4a 5f',
#         b'00 00 78 66 2d 75 57 6e 79 62 cf 33 51 c7 16 86', ...,
#         b'ff fe a2 32 2c 3a 25 17 e7 3d 7b ab 39 1e 2a 92',
#         b'ff ff 89 02 d8 53 2a be da 73 75 98 fb 4a 03 83',
#         b'ff ff d7 35 f3 a8 66 fd 21 7a 78 07 1d 15 0c 78'], dtype=object),
#  'broadcaster_embedding_dimension': 32}

# %% [markdown]
# ### query model

# %%
query_model = QueryModel(cold_start_conf)

# %% [markdown]
# ### broadcaster model

# %%
candidate_model = CandidateModel(cold_start_conf)

# %% [markdown]
# ### two tower model

# %%
metrics = tfrs.metrics.FactorizedTopK(candidates=broadcasters_data_set.batch(128).map(candidate_model))

# %%
task = tfrs.tasks.Retrieval(
    metrics=metrics
)

# %%
from typing import Dict, Text

class TwoTowers(tf.keras.Model):

    def __init__(self, candidate_model, query_model, task):
        super().__init__()
        self.query_model: tf.keras.Model = query_model
        self.candidate_model: tf.keras.Model = candidate_model
        self.task = task

    def train_step(self, features: Dict[Text, tf.Tensor]) -> tf.Tensor:

        # Set up a gradient tape to record gradients.
        with tf.GradientTape() as tape:

            # Loss computation.

            query_embeddings = self.query_model({
                "viewer_gender": features["viewer_gender"],
                "viewer_lang": features["viewer_lang"],
                "viewer_country": features["viewer_country"],
                "viewer_age": features["viewer_age"],
                "viewer_network": features["viewer_network"],
                "viewer_latitude": features["viewer_latitude"],
                "viewer_longitude": features["viewer_longitude"],
                "viewer_lat_long": features["viewer_lat_long"],
            })
            positive_broadcaster_embeddings = self.candidate_model(
                features["broadcaster"])
            loss = self.task(query_embeddings, positive_broadcaster_embeddings)

            # Handle regularization losses as well.
            regularization_loss = sum(self.losses)

            total_loss = loss + regularization_loss

        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(
            zip(gradients, self.trainable_variables))

        metrics = {metric.name: metric.result() for metric in self.metrics}
        metrics["loss"] = loss
        metrics["regularization_loss"] = regularization_loss
        metrics["total_loss"] = total_loss

        return metrics

    def test_step(self, features: Dict[Text, tf.Tensor]) -> tf.Tensor:

        # Loss computation.

        query_embeddings = self.query_model({
                "viewer_gender": features["viewer_gender"],
                "viewer_lang": features["viewer_lang"],
                "viewer_country": features["viewer_country"],
                "viewer_age": features["viewer_age"],
                "viewer_network": features["viewer_network"],
                "viewer_latitude": features["viewer_latitude"],
                "viewer_longitude": features["viewer_longitude"],
                "viewer_lat_long": features["viewer_lat_long"],
        })
        
        positive_broadcaster_embeddings = self.candidate_model(features["broadcaster"])
        loss = self.task(query_embeddings, positive_broadcaster_embeddings)

        # Handle regularization losses as well.
        regularization_loss = sum(self.losses)

        total_loss = loss + regularization_loss

        metrics = {metric.name: metric.result() for metric in self.metrics}
        metrics["loss"] = loss
        metrics["regularization_loss"] = regularization_loss
        metrics["total_loss"] = total_loss
        return metrics

# %%
model = TwoTowers(candidate_model, query_model, task)

# %%
learning_rate = 0.05
batch_size = 16384
# batch_size = 250
epochs = 20
patience = 2
top_k = 1999

# %%
model.compile(optimizer=tf.keras.optimizers.Adagrad(learning_rate=learning_rate))

# %%
tf.random.set_seed(42)
shuffled = train.shuffle(100_000, seed=42, reshuffle_each_iteration=True)

train_p80 = shuffled.take(80_000)
test_p20 = shuffled.skip(80_000).take(20_000)

cached_train = train_p80.shuffle(100_000).batch(batch_size)
cached_test = test_p20.batch(batch_size).cache()

# %%
# model.fit(train_ds, epochs=epochs)
callback = tf.keras.callbacks.EarlyStopping(monitor = "total_loss", 
    patience = patience,
    verbose=1,
    restore_best_weights=True)
new_model_history = model.fit(
    cached_train,
    validation_data=cached_test,
    validation_freq=1,
    epochs=20,
    callbacks = [callback])
# Out:
# Epoch 1/20
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/tensorflow/python/ops/parallel_for/pfor.py:2382: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# WARNING:tensorflow:Using a while_loop for converting BoostedTreesBucketize
# WARNING:tensorflow:Using a while_loop for converting BoostedTreesBucketize
# WARNING:tensorflow:From /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# WARNING:tensorflow:Using a while_loop for converting BoostedTreesBucketize
# 5/5 [==============================] - 564s 117s/step - factorized_top_k/top_1_categorical_accuracy: 7.3750e-04 - factorized_top_k/top_5_categorical_accuracy: 0.0025 - factorized_top_k/top_10_categorical_accuracy: 0.0057 - factorized_top_k/top_50_categorical_accuracy: 0.0150 - factorized_top_k/top_100_categorical_accuracy: 0.0179 - loss: 152937.5964 - regularization_loss: 0.0071 - total_loss: 152937.5964 - val_factorized_top_k/top_1_categorical_accuracy: 1.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0018 - val_factorized_top_k/top_10_categorical_accuracy: 0.0026 - val_factorized_top_k/top_50_categorical_accuracy: 0.0081 - val_factorized_top_k/top_100_categorical_accuracy: 0.0132 - val_loss: 29487.3555 - val_regularization_loss: 0.0076 - val_total_loss: 29487.3633
# Epoch 2/20
# 5/5 [==============================] - 553s 115s/step - factorized_top_k/top_1_categorical_accuracy: 0.0050 - factorized_top_k/top_5_categorical_accuracy: 0.0091 - factorized_top_k/top_10_categorical_accuracy: 0.0132 - factorized_top_k/top_50_categorical_accuracy: 0.0362 - factorized_top_k/top_100_categorical_accuracy: 0.0558 - loss: 150464.1094 - regularization_loss: 0.0078 - total_loss: 150464.1198 - val_factorized_top_k/top_1_categorical_accuracy: 2.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0022 - val_factorized_top_k/top_10_categorical_accuracy: 0.0038 - val_factorized_top_k/top_50_categorical_accuracy: 0.0150 - val_factorized_top_k/top_100_categorical_accuracy: 0.0248 - val_loss: 28785.5312 - val_regularization_loss: 0.0081 - val_total_loss: 28785.5391
# Epoch 3/20
# 5/5 [==============================] - 559s 117s/step - factorized_top_k/top_1_categorical_accuracy: 0.0016 - factorized_top_k/top_5_categorical_accuracy: 0.0067 - factorized_top_k/top_10_categorical_accuracy: 0.0102 - factorized_top_k/top_50_categorical_accuracy: 0.0225 - factorized_top_k/top_100_categorical_accuracy: 0.0320 - loss: 146665.7839 - regularization_loss: 0.0086 - total_loss: 146665.7995 - val_factorized_top_k/top_1_categorical_accuracy: 1.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 9.5000e-04 - val_factorized_top_k/top_10_categorical_accuracy: 0.0018 - val_factorized_top_k/top_50_categorical_accuracy: 0.0093 - val_factorized_top_k/top_100_categorical_accuracy: 0.0179 - val_loss: 28142.3496 - val_regularization_loss: 0.0089 - val_total_loss: 28142.3594
# Epoch 4/20
# 5/5 [==============================] - 560s 117s/step - factorized_top_k/top_1_categorical_accuracy: 0.0023 - factorized_top_k/top_5_categorical_accuracy: 0.0108 - factorized_top_k/top_10_categorical_accuracy: 0.0183 - factorized_top_k/top_50_categorical_accuracy: 0.0563 - factorized_top_k/top_100_categorical_accuracy: 0.0750 - loss: 144496.5547 - regularization_loss: 0.0091 - total_loss: 144496.5677 - val_factorized_top_k/top_1_categorical_accuracy: 1.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0013 - val_factorized_top_k/top_10_categorical_accuracy: 0.0026 - val_factorized_top_k/top_50_categorical_accuracy: 0.0126 - val_factorized_top_k/top_100_categorical_accuracy: 0.0245 - val_loss: 27666.7031 - val_regularization_loss: 0.0094 - val_total_loss: 27666.7129
# Epoch 5/20
# 5/5 [==============================] - 562s 117s/step - factorized_top_k/top_1_categorical_accuracy: 0.0023 - factorized_top_k/top_5_categorical_accuracy: 0.0131 - factorized_top_k/top_10_categorical_accuracy: 0.0246 - factorized_top_k/top_50_categorical_accuracy: 0.0822 - factorized_top_k/top_100_categorical_accuracy: 0.1105 - loss: 142868.8880 - regularization_loss: 0.0096 - total_loss: 142868.9010 - val_factorized_top_k/top_1_categorical_accuracy: 1.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0012 - val_factorized_top_k/top_10_categorical_accuracy: 0.0030 - val_factorized_top_k/top_50_categorical_accuracy: 0.0135 - val_factorized_top_k/top_100_categorical_accuracy: 0.0255 - val_loss: 27305.4766 - val_regularization_loss: 0.0098 - val_total_loss: 27305.4863
# Epoch 6/20
# 5/5 [==============================] - 571s 118s/step - factorized_top_k/top_1_categorical_accuracy: 0.0050 - factorized_top_k/top_5_categorical_accuracy: 0.0192 - factorized_top_k/top_10_categorical_accuracy: 0.0292 - factorized_top_k/top_50_categorical_accuracy: 0.0680 - factorized_top_k/top_100_categorical_accuracy: 0.0864 - loss: 140877.0964 - regularization_loss: 0.0102 - total_loss: 140877.1094 - val_factorized_top_k/top_1_categorical_accuracy: 1.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0014 - val_factorized_top_k/top_10_categorical_accuracy: 0.0033 - val_factorized_top_k/top_50_categorical_accuracy: 0.0163 - val_factorized_top_k/top_100_categorical_accuracy: 0.0299 - val_loss: 27123.1895 - val_regularization_loss: 0.0104 - val_total_loss: 27123.1992
# Epoch 7/20
# 5/5 [==============================] - 569s 119s/step - factorized_top_k/top_1_categorical_accuracy: 0.0033 - factorized_top_k/top_5_categorical_accuracy: 0.0170 - factorized_top_k/top_10_categorical_accuracy: 0.0275 - factorized_top_k/top_50_categorical_accuracy: 0.0668 - factorized_top_k/top_100_categorical_accuracy: 0.0926 - loss: 139627.6693 - regularization_loss: 0.0107 - total_loss: 139627.6823 - val_factorized_top_k/top_1_categorical_accuracy: 4.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0021 - val_factorized_top_k/top_10_categorical_accuracy: 0.0041 - val_factorized_top_k/top_50_categorical_accuracy: 0.0205 - val_factorized_top_k/top_100_categorical_accuracy: 0.0351 - val_loss: 26757.7344 - val_regularization_loss: 0.0110 - val_total_loss: 26757.7461
# Epoch 8/20
# 5/5 [==============================] - 571s 119s/step - factorized_top_k/top_1_categorical_accuracy: 0.0054 - factorized_top_k/top_5_categorical_accuracy: 0.0190 - factorized_top_k/top_10_categorical_accuracy: 0.0279 - factorized_top_k/top_50_categorical_accuracy: 0.0635 - factorized_top_k/top_100_categorical_accuracy: 0.0838 - loss: 137800.8151 - regularization_loss: 0.0113 - total_loss: 137800.8281 - val_factorized_top_k/top_1_categorical_accuracy: 3.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0025 - val_factorized_top_k/top_10_categorical_accuracy: 0.0044 - val_factorized_top_k/top_50_categorical_accuracy: 0.0214 - val_factorized_top_k/top_100_categorical_accuracy: 0.0406 - val_loss: 26701.3633 - val_regularization_loss: 0.0116 - val_total_loss: 26701.3750
# Epoch 9/20
# 5/5 [==============================] - 571s 119s/step - factorized_top_k/top_1_categorical_accuracy: 0.0067 - factorized_top_k/top_5_categorical_accuracy: 0.0242 - factorized_top_k/top_10_categorical_accuracy: 0.0382 - factorized_top_k/top_50_categorical_accuracy: 0.0980 - factorized_top_k/top_100_categorical_accuracy: 0.1257 - loss: 137182.6589 - regularization_loss: 0.0117 - total_loss: 137182.6719 - val_factorized_top_k/top_1_categorical_accuracy: 6.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0030 - val_factorized_top_k/top_10_categorical_accuracy: 0.0058 - val_factorized_top_k/top_50_categorical_accuracy: 0.0209 - val_factorized_top_k/top_100_categorical_accuracy: 0.0388 - val_loss: 26305.5859 - val_regularization_loss: 0.0118 - val_total_loss: 26305.5977
# Epoch 10/20
# 5/5 [==============================] - 572s 119s/step - factorized_top_k/top_1_categorical_accuracy: 0.0047 - factorized_top_k/top_5_categorical_accuracy: 0.0210 - factorized_top_k/top_10_categorical_accuracy: 0.0353 - factorized_top_k/top_50_categorical_accuracy: 0.0825 - factorized_top_k/top_100_categorical_accuracy: 0.1077 - loss: 136144.8594 - regularization_loss: 0.0121 - total_loss: 136144.8750 - val_factorized_top_k/top_1_categorical_accuracy: 5.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0028 - val_factorized_top_k/top_10_categorical_accuracy: 0.0058 - val_factorized_top_k/top_50_categorical_accuracy: 0.0238 - val_factorized_top_k/top_100_categorical_accuracy: 0.0416 - val_loss: 26218.9980 - val_regularization_loss: 0.0122 - val_total_loss: 26219.0098
# Epoch 11/20
# 5/5 [==============================] - 573s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0052 - factorized_top_k/top_5_categorical_accuracy: 0.0222 - factorized_top_k/top_10_categorical_accuracy: 0.0337 - factorized_top_k/top_50_categorical_accuracy: 0.0728 - factorized_top_k/top_100_categorical_accuracy: 0.0926 - loss: 134750.5990 - regularization_loss: 0.0124 - total_loss: 134750.6146 - val_factorized_top_k/top_1_categorical_accuracy: 5.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0038 - val_factorized_top_k/top_10_categorical_accuracy: 0.0065 - val_factorized_top_k/top_50_categorical_accuracy: 0.0244 - val_factorized_top_k/top_100_categorical_accuracy: 0.0416 - val_loss: 26024.3848 - val_regularization_loss: 0.0126 - val_total_loss: 26024.3965
# Epoch 12/20
# 5/5 [==============================] - 573s 119s/step - factorized_top_k/top_1_categorical_accuracy: 0.0046 - factorized_top_k/top_5_categorical_accuracy: 0.0177 - factorized_top_k/top_10_categorical_accuracy: 0.0282 - factorized_top_k/top_50_categorical_accuracy: 0.0657 - factorized_top_k/top_100_categorical_accuracy: 0.0874 - loss: 133953.2995 - regularization_loss: 0.0128 - total_loss: 133953.3151 - val_factorized_top_k/top_1_categorical_accuracy: 5.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0037 - val_factorized_top_k/top_10_categorical_accuracy: 0.0067 - val_factorized_top_k/top_50_categorical_accuracy: 0.0278 - val_factorized_top_k/top_100_categorical_accuracy: 0.0479 - val_loss: 25951.7324 - val_regularization_loss: 0.0129 - val_total_loss: 25951.7461
# Epoch 13/20
# 5/5 [==============================] - 574s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0055 - factorized_top_k/top_5_categorical_accuracy: 0.0208 - factorized_top_k/top_10_categorical_accuracy: 0.0329 - factorized_top_k/top_50_categorical_accuracy: 0.0788 - factorized_top_k/top_100_categorical_accuracy: 0.1080 - loss: 133351.8776 - regularization_loss: 0.0131 - total_loss: 133351.8932 - val_factorized_top_k/top_1_categorical_accuracy: 7.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0036 - val_factorized_top_k/top_10_categorical_accuracy: 0.0071 - val_factorized_top_k/top_50_categorical_accuracy: 0.0291 - val_factorized_top_k/top_100_categorical_accuracy: 0.0530 - val_loss: 25753.7617 - val_regularization_loss: 0.0132 - val_total_loss: 25753.7754
# Epoch 14/20
# 5/5 [==============================] - 576s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0068 - factorized_top_k/top_5_categorical_accuracy: 0.0265 - factorized_top_k/top_10_categorical_accuracy: 0.0411 - factorized_top_k/top_50_categorical_accuracy: 0.0823 - factorized_top_k/top_100_categorical_accuracy: 0.1025 - loss: 132966.7630 - regularization_loss: 0.0134 - total_loss: 132966.7786 - val_factorized_top_k/top_1_categorical_accuracy: 4.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0028 - val_factorized_top_k/top_10_categorical_accuracy: 0.0058 - val_factorized_top_k/top_50_categorical_accuracy: 0.0270 - val_factorized_top_k/top_100_categorical_accuracy: 0.0496 - val_loss: 25796.8789 - val_regularization_loss: 0.0134 - val_total_loss: 25796.8926
# Epoch 15/20
# 5/5 [==============================] - 575s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0066 - factorized_top_k/top_5_categorical_accuracy: 0.0236 - factorized_top_k/top_10_categorical_accuracy: 0.0367 - factorized_top_k/top_50_categorical_accuracy: 0.0785 - factorized_top_k/top_100_categorical_accuracy: 0.1042 - loss: 132251.7083 - regularization_loss: 0.0135 - total_loss: 132251.7240 - val_factorized_top_k/top_1_categorical_accuracy: 4.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0035 - val_factorized_top_k/top_10_categorical_accuracy: 0.0075 - val_factorized_top_k/top_50_categorical_accuracy: 0.0304 - val_factorized_top_k/top_100_categorical_accuracy: 0.0539 - val_loss: 25598.1211 - val_regularization_loss: 0.0135 - val_total_loss: 25598.1348
# Epoch 16/20
# 5/5 [==============================] - 576s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0064 - factorized_top_k/top_5_categorical_accuracy: 0.0211 - factorized_top_k/top_10_categorical_accuracy: 0.0303 - factorized_top_k/top_50_categorical_accuracy: 0.0620 - factorized_top_k/top_100_categorical_accuracy: 0.0847 - loss: 131432.9714 - regularization_loss: 0.0137 - total_loss: 131432.9870 - val_factorized_top_k/top_1_categorical_accuracy: 5.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0048 - val_factorized_top_k/top_10_categorical_accuracy: 0.0088 - val_factorized_top_k/top_50_categorical_accuracy: 0.0356 - val_factorized_top_k/top_100_categorical_accuracy: 0.0589 - val_loss: 25555.5156 - val_regularization_loss: 0.0138 - val_total_loss: 25555.5293
# Epoch 17/20
# 5/5 [==============================] - 576s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0090 - factorized_top_k/top_5_categorical_accuracy: 0.0275 - factorized_top_k/top_10_categorical_accuracy: 0.0396 - factorized_top_k/top_50_categorical_accuracy: 0.0895 - factorized_top_k/top_100_categorical_accuracy: 0.1187 - loss: 130923.8698 - regularization_loss: 0.0139 - total_loss: 130923.8854 - val_factorized_top_k/top_1_categorical_accuracy: 4.5000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0043 - val_factorized_top_k/top_10_categorical_accuracy: 0.0082 - val_factorized_top_k/top_50_categorical_accuracy: 0.0340 - val_factorized_top_k/top_100_categorical_accuracy: 0.0575 - val_loss: 25446.5410 - val_regularization_loss: 0.0140 - val_total_loss: 25446.5547
# Epoch 18/20
# 5/5 [==============================] - 577s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0051 - factorized_top_k/top_5_categorical_accuracy: 0.0156 - factorized_top_k/top_10_categorical_accuracy: 0.0245 - factorized_top_k/top_50_categorical_accuracy: 0.0621 - factorized_top_k/top_100_categorical_accuracy: 0.0903 - loss: 130538.7214 - regularization_loss: 0.0141 - total_loss: 130538.7370 - val_factorized_top_k/top_1_categorical_accuracy: 5.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0046 - val_factorized_top_k/top_10_categorical_accuracy: 0.0089 - val_factorized_top_k/top_50_categorical_accuracy: 0.0358 - val_factorized_top_k/top_100_categorical_accuracy: 0.0615 - val_loss: 25390.5352 - val_regularization_loss: 0.0142 - val_total_loss: 25390.5488
# Epoch 19/20
# 5/5 [==============================] - 576s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0075 - factorized_top_k/top_5_categorical_accuracy: 0.0230 - factorized_top_k/top_10_categorical_accuracy: 0.0340 - factorized_top_k/top_50_categorical_accuracy: 0.0637 - factorized_top_k/top_100_categorical_accuracy: 0.0852 - loss: 130295.0703 - regularization_loss: 0.0143 - total_loss: 130295.0859 - val_factorized_top_k/top_1_categorical_accuracy: 6.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0041 - val_factorized_top_k/top_10_categorical_accuracy: 0.0081 - val_factorized_top_k/top_50_categorical_accuracy: 0.0360 - val_factorized_top_k/top_100_categorical_accuracy: 0.0618 - val_loss: 25557.5469 - val_regularization_loss: 0.0144 - val_total_loss: 25557.5605
# Epoch 20/20
# 5/5 [==============================] - 576s 120s/step - factorized_top_k/top_1_categorical_accuracy: 0.0177 - factorized_top_k/top_5_categorical_accuracy: 0.0496 - factorized_top_k/top_10_categorical_accuracy: 0.0700 - factorized_top_k/top_50_categorical_accuracy: 0.1144 - factorized_top_k/top_100_categorical_accuracy: 0.1327 - loss: 130505.4922 - regularization_loss: 0.0144 - total_loss: 130505.5078 - val_factorized_top_k/top_1_categorical_accuracy: 8.0000e-04 - val_factorized_top_k/top_5_categorical_accuracy: 0.0050 - val_factorized_top_k/top_10_categorical_accuracy: 0.0096 - val_factorized_top_k/top_50_categorical_accuracy: 0.0348 - val_factorized_top_k/top_100_categorical_accuracy: 0.0587 - val_loss: 25344.3398 - val_regularization_loss: 0.0142 - val_total_loss: 25344.3535

# %%
new_model_history.history
# Out:
# {'factorized_top_k/top_1_categorical_accuracy': [0.0007375000277534127,
#   0.004962500184774399,
#   0.0016250000335276127,
#   0.0023250000085681677,
#   0.002287500072270632,
#   0.00501250009983778,
#   0.003312499960884452,
#   0.005400000140070915,
#   0.006662500090897083,
#   0.004737500101327896,
#   0.005212500225752592,
#   0.004637499805539846,
#   0.005549999885261059,
#   0.006825000047683716,
#   0.006550000049173832,
#   0.006424999795854092,
#   0.008962499909102917,
#   0.005062500014901161,
#   0.0075125000439584255,
#   0.017737500369548798],
#  'factorized_top_k/top_5_categorical_accuracy': [0.002537500113248825,
#   0.00911249965429306,
#   0.006687500048428774,
#   0.010787500068545341,
#   0.013100000098347664,
#   0.019237499684095383,
#   0.0170499999076128,
#   0.01899999938905239,
#   0.024150000885128975,
#   0.02097499929368496,
#   0.022237500175833702,
#   0.01772500015795231,
#   0.020800000056624413,
#   0.026512499898672104,
#   0.02356250025331974,
#   0.021062500774860382,
#   0.02745000086724758,
#   0.01563750021159649,
#   0.022974999621510506,
#   0.04964999854564667],
#  'factorized_top_k/top_10_categorical_accuracy': [0.00566249992698431,
#   0.013162500225007534,
#   0.010200000368058681,
#   0.018287500366568565,
#   0.024575000628829002,
#   0.029212500900030136,
#   0.02745000086724758,
#   0.02786250039935112,
#   0.03815000131726265,
#   0.03528749942779541,
#   0.033662501722574234,
#   0.028212500736117363,
#   0.03290000185370445,
#   0.041074998676776886,
#   0.036674998700618744,
#   0.030300000682473183,
#   0.03959999978542328,
#   0.024537499994039536,
#   0.03401250019669533,
#   0.0700249969959259],
#  'factorized_top_k/top_50_categorical_accuracy': [0.015049999579787254,
#   0.0362125001847744,
#   0.022487500682473183,
#   0.056312501430511475,
#   0.08218750357627869,
#   0.06795000284910202,
#   0.06683749705553055,
#   0.06348749995231628,
#   0.09796249866485596,
#   0.08250000327825546,
#   0.07277499884366989,
#   0.06573750078678131,
#   0.07883749902248383,
#   0.08228749781847,
#   0.07851249724626541,
#   0.06199999898672104,
#   0.0895249992609024,
#   0.062062498182058334,
#   0.06372500211000443,
#   0.1143999993801117],
#  'factorized_top_k/top_100_categorical_accuracy': [0.017912499606609344,
#   0.05583750084042549,
#   0.03203750029206276,
#   0.0749875009059906,
#   0.11052499711513519,
#   0.08635000139474869,
#   0.09256249666213989,
#   0.08381249755620956,
#   0.1256749927997589,
#   0.10772500187158585,
#   0.09258750081062317,
#   0.08739999681711197,
#   0.10802499949932098,
#   0.10251250118017197,
#   0.10421250015497208,
#   0.08465000241994858,
#   0.1187250018119812,
#   0.0902625024318695,
#   0.0851999968290329,
#   0.1326874941587448],
#  'loss': [141031.28125,
#   136365.46875,
#   133110.140625,
#   130653.984375,
#   129887.328125,
#   128880.3359375,
#   128196.0078125,
#   125977.5078125,
#   124555.15625,
#   124010.953125,
#   122793.875,
#   122283.515625,
#   121533.90625,
#   121777.5625,
#   120366.25,
#   119851.8671875,
#   119473.203125,
#   119112.84375,
#   119256.59375,
#   118970.796875],
#  'regularization_loss': [0.007762813940644264,
#   0.00792700331658125,
#   0.008739367127418518,
#   0.009224643930792809,
#   0.009672153741121292,
#   0.010444361716508865,
#   0.010874779894948006,
#   0.011507258750498295,
#   0.011701281182467937,
#   0.012083800509572029,
#   0.012613855302333832,
#   0.012898189947009087,
#   0.013208987191319466,
#   0.013330813497304916,
#   0.01357419416308403,
#   0.01374974474310875,
#   0.014019961468875408,
#   0.014148385263979435,
#   0.014332994818687439,
#   0.014365111477673054],
#  'total_loss': [141031.28125,
#   136365.484375,
#   133110.15625,
#   130653.9921875,
#   129887.3359375,
#   128880.34375,
#   128196.015625,
#   125977.515625,
#   124555.1640625,
#   124010.96875,
#   122793.890625,
#   122283.53125,
#   121533.921875,
#   121777.578125,
#   120366.265625,
#   119851.8828125,
#   119473.21875,
#   119112.859375,
#   119256.609375,
#   118970.8125],
#  'val_factorized_top_k/top_1_categorical_accuracy': [0.0001500000071246177,
#   0.0002500000118743628,
#   0.0001500000071246177,
#   0.0001500000071246177,
#   0.0001500000071246177,
#   0.0001500000071246177,
#   0.00039999998989515007,
#   0.0003000000142492354,
#   0.0006000000284984708,
#   0.0005499999970197678,
#   0.0005000000237487257,
#   0.0005499999970197678,
#   0.000750000006519258,
#   0.00044999999227002263,
#   0.00044999999227002263,
#   0.0005499999970197678,
#   0.00044999999227002263,
#   0.0005000000237487257,
#   0.0006000000284984708,
#   0.0007999999797903001],
#  'val_factorized_top_k/top_5_categorical_accuracy': [0.0017999999690800905,
#   0.002199999988079071,
#   0.0009500000160187483,
#   0.0013000000035390258,
#   0.0012000000569969416,
#   0.001449999981559813,
#   0.002050000010058284,
#   0.0024999999441206455,
#   0.0030499999411404133,
#   0.00279999990016222,
#   0.003800000064074993,
#   0.0037499999161809683,
#   0.003599999938160181,
#   0.00279999990016222,
#   0.0035000001080334187,
#   0.004800000227987766,
#   0.0042500002309679985,
#   0.004600000102072954,
#   0.004100000020116568,
#   0.005049999803304672],
#  'val_factorized_top_k/top_10_categorical_accuracy': [0.0025500000920146704,
#   0.003800000064074993,
#   0.0017500000540167093,
#   0.0026000000070780516,
#   0.003000000026077032,
#   0.0032999999821186066,
#   0.004149999935179949,
#   0.004449999891221523,
#   0.005849999841302633,
#   0.005799999926239252,
#   0.0064500002190470695,
#   0.0066999997943639755,
#   0.0071000000461936,
#   0.005799999926239252,
#   0.007499999832361937,
#   0.008799999952316284,
#   0.008249999955296516,
#   0.008949999697506428,
#   0.008050000295042992,
#   0.009600000455975533],
#  'val_factorized_top_k/top_50_categorical_accuracy': [0.008050000295042992,
#   0.015049999579787254,
#   0.009349999949336052,
#   0.012649999931454659,
#   0.013450000435113907,
#   0.016300000250339508,
#   0.020500000566244125,
#   0.021449999883770943,
#   0.02085000090301037,
#   0.023800000548362732,
#   0.0243500005453825,
#   0.027799999341368675,
#   0.02905000001192093,
#   0.027000000700354576,
#   0.03044999949634075,
#   0.03564999997615814,
#   0.03395000100135803,
#   0.035750001668930054,
#   0.03595000132918358,
#   0.03480000048875809],
#  'val_factorized_top_k/top_100_categorical_accuracy': [0.013199999928474426,
#   0.02484999969601631,
#   0.017899999395012856,
#   0.02449999935925007,
#   0.025499999523162842,
#   0.029850000515580177,
#   0.03514999896287918,
#   0.040550000965595245,
#   0.03884999826550484,
#   0.041600000113248825,
#   0.041600000113248825,
#   0.04794999957084656,
#   0.05299999937415123,
#   0.04964999854564667,
#   0.05389999970793724,
#   0.0588500015437603,
#   0.05745000019669533,
#   0.061500001698732376,
#   0.061799999326467514,
#   0.05874999985098839],
#  'val_loss': [29487.35546875,
#   28785.53125,
#   28142.349609375,
#   27666.703125,
#   27305.4765625,
#   27123.189453125,
#   26757.734375,
#   26701.36328125,
#   26305.5859375,
#   26218.998046875,
#   26024.384765625,
#   25951.732421875,
#   25753.76171875,
#   25796.87890625,
#   25598.12109375,
#   25555.515625,
#   25446.541015625,
#   25390.53515625,
#   25557.546875,
#   25344.33984375],
#  'val_regularization_loss': [0.007587719708681107,
#   0.008137745782732964,
#   0.008926806040108204,
#   0.009350180625915527,
#   0.009777973406016827,
#   0.010384389199316502,
#   0.011003184132277966,
#   0.011581217870116234,
#   0.011827435344457626,
#   0.01219135895371437,
#   0.01256117969751358,
#   0.01292956992983818,
#   0.013233433477580547,
#   0.01338887307792902,
#   0.013521954417228699,
#   0.013830763287842274,
#   0.013956368900835514,
#   0.01418132334947586,
#   0.014361800625920296,
#   0.014234701171517372],
#  'val_total_loss': [29487.36328125,
#   28785.5390625,
#   28142.359375,
#   27666.712890625,
#   27305.486328125,
#   27123.19921875,
#   26757.74609375,
#   26701.375,
#   26305.59765625,
#   26219.009765625,
#   26024.396484375,
#   25951.74609375,
#   25753.775390625,
#   25796.892578125,
#   25598.134765625,
#   25555.529296875,
#   25446.5546875,
#   25390.548828125,
#   25557.560546875,
#   25344.353515625]}

# %%
accuracy = new_model_history.history["factorized_top_k/top_100_categorical_accuracy"][-1]
print(f"Top-100 accuracy: {accuracy:.4f}.")
# Out:
# Top-100 accuracy: 0.1327.

# %%
val_accuracy = new_model_history.history["val_factorized_top_k/top_100_categorical_accuracy"][-1]
print(f"Top-100 accuracy: {val_accuracy:.4f}.")
# Out:
# Top-100 accuracy: 0.0587.

# %%
idx = np.argmin(new_model_history.history["total_loss"])
accuracy = new_model_history.history["factorized_top_k/top_100_categorical_accuracy"][idx]
print(f"Top-100 accuracy: {accuracy:.4f}.")
val_accuracy = new_model_history.history["val_factorized_top_k/top_100_categorical_accuracy"][idx]
print(f"Top-100 accuracy: {val_accuracy:.4f}.")
# Out:
# Top-100 accuracy: 0.1327.
# Top-100 accuracy: 0.0587.
