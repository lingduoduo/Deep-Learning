# %%
import torch

torch.manual_seed(1)
mean = torch.rand(1, 2) * 100
print(mean)
# Out:
# tensor([[75.7632, 27.9311]])

# %%
std  = torch.rand(1, 2)
print(std)
# Out:
# tensor([[0.4031, 0.7347]])

# %%
print(torch.normal(mean, std))
# Out:
# tensor([[75.7880, 28.3876]])
