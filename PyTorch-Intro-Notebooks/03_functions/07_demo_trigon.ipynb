# %%
import torch

a = torch.zeros(2, 3)
b = torch.cos(a)
print(b)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
a = torch.zeros(2, 3)
b = torch.sin(a)
print(b)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
