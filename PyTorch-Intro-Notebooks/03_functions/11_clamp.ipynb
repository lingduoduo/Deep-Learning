# %%
import torch

a = torch.rand(2, 2) * 10

# %%
print(a)
# Out:
# tensor([[2.3891, 8.0555],
#         [2.7399, 8.9034]])

# %%
a = a.clamp(2, 5)

# %%
print(a)
# Out:
# tensor([[2.3891, 5.0000],
#         [2.7399, 5.0000]])
