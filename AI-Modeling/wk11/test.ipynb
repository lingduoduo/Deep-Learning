# %%
import numpy as np

grid = np.arange(25).reshape([5,5])
it = np.nditer(grid, flags=['multi_index'])

# %%
for i in it:
    print(i.multi_index)

# %%
s = it.iterindex
y, x = it.multi_index

# %%
y
# Out:
# 0

# %%
x
# Out:
# 0
