# %%
# Please install OpenAI SDK first: `pip3 install openai`

from openai import OpenAI

client = OpenAI(api_key="sk-200c5b1c8bb0408ab3a5d034cae42f8f", base_url="https://api.deepseek.com")

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "Hello"},
    ],
    stream=False
)

print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today? 😊

# %%
0.05**(-0.2)
# Out:
# 1.8205642030260802

# %%
0.05**(-0.3)
# Out:
# 2.4564560522315806

# %%
0.05**(-0.5)
# Out:
# 4.47213595499958

# %%
0.05**(-0.9)
# Out:
# 14.822688982138954

# %%
0.05**(-1)
# Out:
# 20.0
