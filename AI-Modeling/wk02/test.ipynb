# %%
#模型下载
from modelscope import snapshot_download
model_dir = snapshot_download('Qwen/Qwen3-0.6B', cache_dir="./")
# Out:
# 2025-06-08 21:30:58,638 - modelscope - INFO - PyTorch version 2.7.0 Found.
# 2025-06-08 21:30:58,642 - modelscope - INFO - Loading ast index from C:\Users\Lenovo\.cache\modelscope\ast_indexer
# 2025-06-08 21:30:59,038 - modelscope - INFO - Loading done! Current index file version is 1.15.0, with md5 860420f57ac3be363bbf1db2484ea385 and a total number of 980 components indexed
# Downloading: 100%|██████████| 726/726 [00:01<00:00, 550B/s]
# Downloading: 100%|██████████| 73.0/73.0 [00:01<00:00, 56.9B/s]
# Downloading: 100%|██████████| 239/239 [00:01<00:00, 186B/s]
# Downloading: 100%|██████████| 1.59M/1.59M [00:01<00:00, 1.28MB/s]
# Downloading: 100%|██████████| 1.40G/1.40G [01:47<00:00, 14.0MB/s]
# Downloading: 100%|██████████| 13.6k/13.6k [00:01<00:00, 12.8kB/s]
# Downloading: 100%|██████████| 10.9M/10.9M [00:01<00:00, 7.57MB/s]
# Downloading: 100%|██████████| 9.50k/9.50k [00:01<00:00, 7.82kB/s]
# Downloading: 100%|██████████| 2.65M/2.65M [00:01<00:00, 1.93MB/s]

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-0___6B")

# %%
model = AutoModelForCausalLM.from_pretrained(
    "Qwen/Qwen3-0___6B"
)

# %%
# prepare the model input
prompt = "Give me a short introduction to large language model."
messages = [
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True,
    enable_thinking=True # Switches between thinking and non-thinking modes. Default is True.
)
model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

# conduct text completion
generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32768
)
output_ids = generated_ids[0][len(model_inputs.input_ids[0]):].tolist() 

# parsing thinking content
try:
    # rindex finding 151668 (</think>)
    index = len(output_ids) - output_ids[::-1].index(151668)
except ValueError:
    index = 0

thinking_content = tokenizer.decode(output_ids[:index], skip_special_tokens=True).strip("\n")
content = tokenizer.decode(output_ids[index:], skip_special_tokens=True).strip("\n")

print("thinking content:", thinking_content)
print("content:", content)
# Out:
# thinking content: <think>
# Okay, the user wants a short introduction to a large language model. Let me start by recalling what a large language model is. It's a type of artificial intelligence that can understand and generate human language. I should mention that it's trained on massive datasets to understand a wide range of topics.
#
# I need to highlight its key features: ability to understand and generate text, adapt to different languages, and handle various tasks like writing, answering questions, etc. Also, maybe mention that it's used in many applications like chatbots, content creation, and language translation.
#
# Wait, the user asked for a short introduction. So I shouldn't go too detailed. Keep it concise but informative. Avoid technical jargon if possible. Make sure it's friendly and addresses the user's need without being too technical. Let me check if I covered all the main points: definition, purpose, features, applications, and maybe a brief example. Yes, that should work. Let me put it all together in a clear and friendly way.
# </think>
# content: A large language model (LLM) is a type of artificial intelligence designed to understand and generate human language. It processes vast amounts of text from large datasets, enabling it to comprehend complex topics, languages, and contexts. These models can answer questions, create content, and perform various tasks like writing, translation, and summarization. They are widely used in applications such as chatbots, language assistants, and content creation.

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- ---------------
# addict                                   2.4.0
# aiobotocore                              2.7.0
# aiohttp                                  3.9.3
# aioitertools                             0.7.1
# aiosignal                                1.2.0
# alabaster                                0.7.12
# aliyun-python-sdk-core                   2.15.1
# aliyun-python-sdk-kms                    2.16.3
# altair                                   5.0.1
# anaconda-anon-usage                      0.4.3
# anaconda-catalogs                        0.2.0
# anaconda-client                          1.12.3
# anaconda-cloud-auth                      0.1.4
# anaconda-navigator                       2.5.2
# anaconda-project                         0.11.1
# anthropic                                0.34.1
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.2.0
# appdirs                                  1.4.4
# archspec                                 0.2.1
# argon2-cffi                              21.3.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.2.3
# asgiref                                  3.8.1
# astroid                                  2.14.2
# astropy                                  5.3.4
# asttokens                                2.0.5
# async-lru                                2.0.4
# atomicwrites                             1.4.0
# attrs                                    24.2.0
# audioread                                3.0.1
# Automat                                  20.2.0
# autopep8                                 1.6.0
# Babel                                    2.11.0
# backoff                                  2.2.1
# backports.functools-lru-cache            1.6.4
# backports.tempfile                       1.0
# backports.weakref                        1.0.post1
# bcrypt                                   4.2.0
# beautifulsoup4                           4.12.2
# binaryornot                              0.4.4
# black                                    23.11.0
# bleach                                   4.1.0
# blinker                                  1.6.2
# bokeh                                    3.3.4
# boltons                                  23.0.0
# botocore                                 1.31.64
# Bottleneck                               1.3.7
# Brotli                                   1.0.9
# build                                    1.2.1
# cachetools                               4.2.2
# certifi                                  2024.2.2
# cffi                                     1.16.0
# chardet                                  4.0.0
# charset-normalizer                       3.3.2
# chroma-hnswlib                           0.7.3
# chromadb                                 0.5.3
# click                                    8.1.7
# cloudpickle                              2.2.1
# clyent                                   1.2.2
# colorama                                 0.4.6
# colorcet                                 3.0.1
# coloredlogs                              15.0.1
# comm                                     0.1.2
# conda                                    24.1.2
# conda-build                              24.1.2
# conda-content-trust                      0.2.0
# conda_index                              0.4.0
# conda-libmamba-solver                    24.1.0
# conda-pack                               0.6.0
# conda-package-handling                   2.2.0
# conda_package_streaming                  0.9.0
# conda-repo-cli                           1.0.75
# conda-token                              0.4.0
# conda-verify                             3.4.2
# constantly                               23.10.4
# contourpy                                1.2.0
# cookiecutter                             2.5.0
# crcmod                                   1.7
# cryptography                             42.0.2
# cssselect                                1.2.0
# cycler                                   0.11.0
# cytoolz                                  0.12.2
# dashscope                                1.20.3
# dask                                     2023.11.0
# dataclasses-json                         0.6.7
# DataRecorder                             3.5.3
# datasets                                 2.18.0
# datashader                               0.16.0
# debugpy                                  1.6.7
# decorator                                4.4.2
# deepdiff                                 7.0.1
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# deprecation                              2.1.0
# diff-match-patch                         20200713
# dill                                     0.3.8
# distributed                              2023.11.0
# distro                                   1.8.0
# dnspython                                2.6.1
# docstring-to-markdown                    0.11
# docutils                                 0.18.1
# DownloadKit                              2.0.4
# DrissionPage                             4.1.0.6
# effdet                                   0.4.1
# einops                                   0.8.0
# email_validator                          2.2.0
# emoji                                    2.12.1
# entrypoints                              0.4
# et-xmlfile                               1.1.0
# executing                                0.8.3
# fake-useragent                           1.5.1
# fastapi                                  0.111.0
# fastapi-cli                              0.0.4
# fastjsonschema                           2.16.2
# filelock                                 3.13.1
# filetype                                 1.2.0
# flake8                                   6.0.0
# Flask                                    2.2.5
# flatbuffers                              24.3.25
# fonttools                                4.25.0
# frozenlist                               1.4.0
# fsspec                                   2023.10.0
# future                                   0.18.3
# gast                                     0.5.4
# gensim                                   4.3.0
# gitdb                                    4.0.7
# GitPython                                3.1.37
# gmpy2                                    2.1.2
# google-api-core                          2.19.1
# google-auth                              2.30.0
# google-cloud-vision                      3.7.2
# googleapis-common-protos                 1.63.2
# greenlet                                 3.0.1
# groq                                     0.9.0
# grpcio                                   1.64.1
# grpcio-status                            1.62.2
# h11                                      0.14.0
# h5py                                     3.9.0
# HeapDict                                 1.0.1
# holoviews                                1.18.3
# httpcore                                 1.0.5
# httptools                                0.6.1
# httpx                                    0.27.0
# huggingface-hub                          0.32.0
# humanfriendly                            10.0
# hvplot                                   0.9.2
# hyperlink                                21.0.0
# idna                                     3.4
# imagecodecs                              2023.1.23
# imageio                                  2.33.1
# imageio-ffmpeg                           0.5.1
# imagesize                                1.4.1
# imbalanced-learn                         0.11.0
# importlib-metadata                       7.0.1
# importlib_resources                      6.4.2
# incremental                              22.10.0
# inflection                               0.5.1
# iniconfig                                1.1.1
# intake                                   0.6.8
# intel-openmp                             2021.4.0
# intervaltree                             3.1.0
# iopath                                   0.1.10
# ipykernel                                6.28.0
# ipython                                  8.20.0
# ipython-genutils                         0.2.0
# ipywidgets                               7.6.5
# isort                                    5.9.3
# itemadapter                              0.3.0
# itemloaders                              1.1.0
# itsdangerous                             2.0.1
# jaraco.classes                           3.2.1
# jedi                                     0.18.1
# jellyfish                                1.0.1
# jieba                                    0.42.1
# Jinja2                                   3.1.3
# jiter                                    0.5.0
# jmespath                                 0.10.0
# joblib                                   1.2.0
# json5                                    0.9.6
# jsonlines                                4.0.0
# jsonpatch                                1.33
# jsonpath-python                          1.0.6
# jsonpointer                              2.1
# jsonschema                               4.19.2
# jsonschema-specifications                2023.7.1
# jupyter                                  1.0.0
# jupyter_client                           8.6.0
# jupyter-console                          6.6.3
# jupyter_core                             5.5.0
# jupyter-events                           0.8.0
# jupyter-lsp                              2.2.0
# jupyter_server                           2.10.0
# jupyter_server_terminals                 0.4.4
# jupyterlab                               4.0.11
# jupyterlab-pygments                      0.1.2
# jupyterlab_server                        2.25.1
# jupyterlab-widgets                       3.0.9
# keyring                                  23.13.1
# kiwisolver                               1.4.4
# kubernetes                               30.1.0
# lancedb                                  0.9.0
# langchain                                0.2.7
# langchain-anthropic                      0.1.23
# langchain-chroma                         0.1.2
# langchain-community                      0.2.7
# langchain-core                           0.2.35
# langchain-openai                         0.1.22
# langchain-text-splitters                 0.2.0
# langchainhub                             0.1.20
# langdetect                               1.0.9
# langgraph                                0.2.14
# langgraph-checkpoint                     1.0.6
# langsmith                                0.1.85
# layoutparser                             0.3.4
# lazy_loader                              0.3
# lazy-object-proxy                        1.6.0
# lckr_jupyterlab_variableinspector        3.1.0
# libarchive-c                             2.9
# libmambapy                               1.5.6
# librosa                                  0.10.2.post1
# linkify-it-py                            2.0.0
# llvmlite                                 0.42.0
# lmdb                                     1.4.1
# locket                                   1.0.0
# loguru                                   0.7.2
# lxml                                     4.9.3
# lz4                                      4.3.2
# Markdown                                 3.4.1
# markdown-it-py                           2.2.0
# MarkupSafe                               2.1.3
# marshmallow                              3.21.3
# matplotlib                               3.8.0
# matplotlib-inline                        0.1.6
# mccabe                                   0.7.0
# mdit-py-plugins                          0.3.0
# mdurl                                    0.1.0
# menuinst                                 2.0.2
# mistune                                  2.0.4
# mkl                                      2021.4.0
# mkl-fft                                  1.3.8
# mkl-random                               1.2.4
# mkl-service                              2.4.0
# mmh3                                     4.1.0
# modelscope                               1.15.0
# monotonic                                1.6
# more-itertools                           10.1.0
# MouseInfo                                0.1.3
# moviepy                                  1.0.3
# mpmath                                   1.3.0
# msgpack                                  1.0.3
# multidict                                6.0.4
# multipledispatch                         0.6.0
# multiprocess                             0.70.16
# munkres                                  1.1.4
# mypy                                     1.8.0
# mypy-extensions                          1.0.0
# mysql                                    0.0.3
# mysql-connector-python                   9.0.0
# mysqlclient                              2.2.4
# navigator-updater                        0.4.0
# nbclient                                 0.8.0
# nbconvert                                7.10.0
# nbformat                                 5.9.2
# nest-asyncio                             1.6.0
# networkx                                 3.1
# nltk                                     3.8.1
# notebook                                 7.0.8
# notebook_shim                            0.2.3
# numba                                    0.59.0
# numexpr                                  2.8.7
# numpy                                    1.26.4
# numpydoc                                 1.5.0
# oauthlib                                 3.2.2
# olefile                                  0.47
# omegaconf                                2.3.0
# onnx                                     1.16.1
# onnxruntime                              1.18.0
# openai                                   1.73.0
# opencv-python                            4.10.0.84
# openpyxl                                 3.0.10
# opentelemetry-api                        1.26.0
# opentelemetry-exporter-otlp-proto-common 1.26.0
# opentelemetry-exporter-otlp-proto-grpc   1.26.0
# opentelemetry-instrumentation            0.47b0
# opentelemetry-instrumentation-asgi       0.47b0
# opentelemetry-instrumentation-fastapi    0.47b0
# opentelemetry-proto                      1.26.0
# opentelemetry-sdk                        1.26.0
# opentelemetry-semantic-conventions       0.47b0
# opentelemetry-util-http                  0.47b0
# ordered-set                              4.1.0
# orjson                                   3.10.3
# oss2                                     2.18.6
# outcome                                  1.3.0.post0
# overrides                                7.4.0
# packaging                                23.2
# pandas                                   2.1.4
# pandocfilters                            1.5.0
# panel                                    1.3.8
# param                                    2.0.2
# paramiko                                 2.8.1
# parsel                                   1.8.1
# parso                                    0.8.3
# partd                                    1.4.1
# pathlib                                  1.0.1
# pathspec                                 0.10.3
# patsy                                    0.5.3
# pdf2image                                1.17.0
# pdfminer.six                             20231228
# pdfplumber                               0.11.1
# pexpect                                  4.8.0
# pickleshare                              0.7.5
# pikepdf                                  9.0.0
# pillow                                   10.2.0
# pillow_heif                              0.16.0
# pip                                      25.1.1
# pkce                                     1.0.3
# pkginfo                                  1.9.6
# platformdirs                             3.10.0
# plotly                                   5.9.0
# pluggy                                   1.0.0
# ply                                      3.11
# pooch                                    1.8.2
# portalocker                              2.10.0
# posthog                                  3.5.0
# proglog                                  0.1.10
# prometheus-client                        0.14.1
# prompt-toolkit                           3.0.43
# Protego                                  0.1.16
# proto-plus                               1.24.0
# protobuf                                 4.25.3
# psutil                                   5.9.0
# ptyprocess                               0.7.0
# pure-eval                                0.2.2
# py                                       1.11.0
# py-cpuinfo                               9.0.0
# pyarrow                                  14.0.2
# pyarrow-hotfix                           0.6
# pyasn1                                   0.4.8
# pyasn1-modules                           0.2.8
# PyAutoGUI                                0.9.54
# pycocotools                              2.0.8
# pycodestyle                              2.10.0
# pycosat                                  0.6.6
# pycparser                                2.21
# pycryptodome                             3.20.0
# pyct                                     0.5.0
# pycurl                                   7.45.2
# pydantic                                 1.10.12
# pydeck                                   0.8.0
# PyDispatcher                             2.0.5
# pydocstyle                               6.3.0
# pydub                                    0.25.1
# pyerfa                                   2.0.0
# pyext                                    0.5.1
# pyflakes                                 3.0.1
# PyGetWindow                              0.0.9
# Pygments                                 2.15.1
# PyJWT                                    2.4.0
# pylance                                  0.13.0
# pylint                                   2.16.2
# pylint-venv                              2.3.0
# pyls-spyder                              0.4.0
# PyMsgBox                                 1.0.9
# PyNaCl                                   1.5.0
# pynput                                   1.7.7
# pyodbc                                   5.0.1
# pyOpenSSL                                24.0.0
# pypandoc                                 1.13
# pyparsing                                3.0.9
# pypdf                                    4.2.0
# pypdfium2                                4.30.0
# pyperclip                                1.9.0
# PyPika                                   0.48.9
# pyproject_hooks                          1.1.0
# PyQt5                                    5.15.10
# PyQt5-sip                                12.13.0
# PyQtWebEngine                            5.15.6
# pyreadline3                              3.4.1
# PyRect                                   0.2.0
# PyScreeze                                1.0.1
# PySocks                                  1.7.1
# pytesseract                              0.3.10
# pytest                                   7.4.0
# python-dateutil                          2.8.2
# python-docx                              1.1.2
# python-dotenv                            0.21.0
# python-iso639                            2024.4.27
# python-json-logger                       2.0.7
# python-lsp-black                         1.2.1
# python-lsp-jsonrpc                       1.0.0
# python-lsp-server                        1.7.2
# python-magic                             0.4.27
# python-multipart                         0.0.9
# python-oxmsg                             0.0.1
# python-pptx                              0.6.23
# python-slugify                           5.0.2
# python-snappy                            0.6.1
# pytoolconfig                             1.2.6
# pytweening                               1.2.0
# pytz                                     2023.3.post1
# pyviz_comms                              3.0.0
# pywavelets                               1.5.0
# pywin32                                  305.1
# pywin32-ctypes                           0.2.0
# pywinpty                                 2.0.10
# PyYAML                                   6.0.1
# pyzmq                                    25.1.2
# QDarkStyle                               3.0.2
# qstylizer                                0.2.2
# QtAwesome                                1.2.2
# qtconsole                                5.4.2
# QtPy                                     2.4.1
# queuelib                                 1.6.2
# rapidfuzz                                3.9.3
# ratelimiter                              1.2.0.post0
# referencing                              0.30.2
# regex                                    2023.10.3
# requests                                 2.31.0
# requests-file                            1.5.1
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# retry                                    0.9.2
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.3.5
# rope                                     1.7.0
# rpds-py                                  0.10.6
# rsa                                      4.9
# Rtree                                    1.0.1
# ruamel.yaml                              0.17.21
# ruamel-yaml-conda                        0.17.21
# s3fs                                     2023.10.0
# safetensors                              0.5.3
# scikit-image                             0.22.0
# scikit-learn                             1.2.2
# scipy                                    1.11.4
# Scrapy                                   2.8.0
# seaborn                                  0.12.2
# selenium                                 4.25.0
# semver                                   2.13.0
# Send2Trash                               1.8.2
# sentence-transformers                    4.1.0
# service-identity                         18.1.0
# setuptools                               68.2.2
# shellingham                              1.5.4
# simplejson                               3.19.2
# sip                                      6.7.12
# six                                      1.16.0
# smart-open                               5.2.1
# smmap                                    4.0.0
# sniffio                                  1.3.0
# snowballstemmer                          2.2.0
# sortedcontainers                         2.4.0
# soundfile                                0.12.1
# soupsieve                                2.5
# soxr                                     0.5.0.post1
# Sphinx                                   5.0.2
# sphinxcontrib-applehelp                  1.0.2
# sphinxcontrib-devhelp                    1.0.2
# sphinxcontrib-htmlhelp                   2.0.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     1.0.3
# sphinxcontrib-serializinghtml            1.1.5
# spyder                                   5.4.3
# spyder-kernels                           2.4.4
# SQLAlchemy                               2.0.25
# stack-data                               0.2.0
# starlette                                0.37.2
# staticvectors                            0.2.0
# statsmodels                              0.14.0
# streamlit                                1.30.0
# sympy                                    1.14.0
# tables                                   3.9.2
# tabulate                                 0.9.0
# tbb                                      2021.13.0
# tblib                                    1.7.0
# tenacity                                 8.5.0
# terminado                                0.17.1
# tesseract                                0.1.3
# text-unidecode                           1.3
# text2vec                                 1.2.9
# textdistance                             4.2.1
# threadpoolctl                            2.2.0
# three-merge                              0.1.1
# tifffile                                 2023.4.12
# tiktoken                                 0.7.0
# timm                                     1.0.7
# tinycss2                                 1.2.1
# tldextract                               3.2.0
# tokenizers                               0.21.1
# toml                                     0.10.2
# tomlkit                                  0.11.1
# toolz                                    0.12.0
# torch                                    2.7.0
# torchvision                              0.22.0
# tornado                                  6.3.3
# tqdm                                     4.65.0
# traitlets                                5.7.1
# transformers                             4.51.1
# trio                                     0.27.0
# trio-websocket                           0.11.1
# truststore                               0.8.0
# Twisted                                  23.10.0
# twisted-iocpsupport                      1.0.2
# typer                                    0.12.3
# types-requests                           2.32.0.20240622
# typing_extensions                        4.12.2
# typing-inspect                           0.9.0
# tzdata                                   2023.3
# tzlocal                                  2.1
# uc-micro-py                              1.0.1
# ujson                                    5.4.0
# Unidecode                                1.2.0
# unstructured                             0.14.8
# unstructured-client                      0.23.7
# unstructured-inference                   0.7.36
# unstructured.pytesseract                 0.3.12
# urllib3                                  2.0.7
# uvicorn                                  0.30.1
# validators                               0.18.2
# volcengine-python-sdk                    1.0.110
# w3lib                                    2.1.2
# watchdog                                 2.1.6
# watchfiles                               0.22.0
# wcwidth                                  0.2.5
# webencodings                             0.5.1
# websocket-client                         1.8.0
# websockets                               12.0
# Werkzeug                                 2.2.3
# wget                                     3.2
# whatthepatch                             1.0.2
# wheel                                    0.41.2
# widgetsnbextension                       3.5.2
# wikipedia                                1.4.0
# win-inet-pton                            1.1.0
# win32-setctime                           1.1.0
# wrapt                                    1.14.1
# wsproto                                  1.2.0
# xarray                                   2023.6.0
# xlrd                                     2.0.1
# XlsxWriter                               3.2.0
# xlwings                                  0.29.1
# xxhash                                   3.4.1
# xyzservices                              2022.9.0
# yapf                                     0.31.0
# yarl                                     1.9.3
# zict                                     3.0.0
# zipp                                     3.17.0
# zope.interface                           5.4.0
# zstandard                                0.19.0
# WARNING: Ignoring invalid distribution ~orch (C:\anaconda\Lib\site-packages)

# %%
# pip install transformers==4.51.1
# pip install torch==2.7.0
