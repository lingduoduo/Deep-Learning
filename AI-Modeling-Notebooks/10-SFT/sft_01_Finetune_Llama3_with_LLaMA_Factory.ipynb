# %% [markdown]
# <a href="https://colab.research.google.com/github/lingduoduo/Deep-Learning/blob/master/Finetune_Llama3_with_LLaMA_Factory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Finetune Llama-3 with LLaMA Factory
#
# Please use a **free** Tesla T4 Colab GPU to run this!
#
# Project homepage: https://github.com/hiyouga/LLaMA-Factory

# %% [markdown]
# ## Install Dependencies

# %%
# %cd /content/
# %rm -rf LLaMA-Factory
# !git clone --depth 1 https://github.com/hiyouga/LLaMA-Factory.git
# %cd LLaMA-Factory
# %ls
# !pip install -e .[torch,bitsandbytes]
# Out:
# /content
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 450, done.
# remote: Counting objects: 100% (450/450), done.
# remote: Compressing objects: 100% (341/341), done.
# remote: Total 450 (delta 116), reused 331 (delta 91), pack-reused 0 (from 0)
# Receiving objects: 100% (450/450), 5.15 MiB | 19.04 MiB/s, done.
# Resolving deltas: 100% (116/116), done.
# /content/LLaMA-Factory
# assets/       docker/    Makefile        README.md         scripts/  tests/
# CITATION.cff  examples/  MANIFEST.in     README_zh.md      setup.py  tests_v1/
# data/         LICENSE    pyproject.toml  requirements.txt  src/
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers!=4.52.0,!=4.57.0,<=4.57.1,>=4.49.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (4.57.1)
# Requirement already satisfied: datasets<=4.0.0,>=2.16.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (4.0.0)
# Requirement already satisfied: accelerate<=1.11.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (1.11.0)
# Requirement already satisfied: peft<=0.17.1,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.17.1)
# Requirement already satisfied: trl<=0.9.6,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.9.6)
# Requirement already satisfied: gradio<=5.45.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (5.45.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (3.10.0)
# Requirement already satisfied: tyro<0.9.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.8.14)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.8.1)
# Requirement already satisfied: numpy<2.0.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (1.16.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.2.1)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.12.0)
# Requirement already satisfied: modelscope>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (1.32.0)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.1.9)
# Requirement already satisfied: safetensors<=0.5.3 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.5.3)
# Requirement already satisfied: fire in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.7.1)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (2.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (25.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (6.0.3)
# Requirement already satisfied: pydantic<=2.10.6 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (2.10.6)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.38.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.118.3)
# Requirement already satisfied: sse-starlette in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (3.0.3)
# Requirement already satisfied: av in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (16.0.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.11.0)
# Requirement already satisfied: propcache!=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.4.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.24.0+cu126)
# Requirement already satisfied: bitsandbytes>=0.39.0 in /usr/local/lib/python3.12/dist-packages (from llamafactory==0.9.4.dev0) (0.48.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.4.dev0) (5.9.5)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.4.dev0) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (2025.3.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (4.11.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (1.2.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (1.0.0)
# Requirement already satisfied: gradio-client==1.13.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (1.13.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (3.11.4)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.14.5)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.12/dist-packages (from gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (4.15.0)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.0->gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (15.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.4.dev0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.4.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.4.dev0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.4.dev0) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.4.dev0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.4.dev0) (2.9.0.post0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from modelscope>=1.14.0->llamafactory==0.9.4.dev0) (75.2.0)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.12/dist-packages (from modelscope>=1.14.0->llamafactory==0.9.4.dev0) (2.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->llamafactory==0.9.4.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->llamafactory==0.9.4.dev0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.10.6->llamafactory==0.9.4.dev0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.10.6->llamafactory==0.9.4.dev0) (2.27.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (3.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->llamafactory==0.9.4.dev0) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.57.0,<=4.57.1,>=4.49.0->llamafactory==0.9.4.dev0) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.57.0,<=4.57.1,>=4.49.0->llamafactory==0.9.4.dev0) (0.22.1)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.12/dist-packages (from tyro<0.9.0->llamafactory==0.9.4.dev0) (0.17.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.12/dist-packages (from tyro<0.9.0->llamafactory==0.9.4.dev0) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from tyro<0.9.0->llamafactory==0.9.4.dev0) (1.8.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn->llamafactory==0.9.4.dev0) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->llamafactory==0.9.4.dev0) (0.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->llamafactory==0.9.4.dev0) (3.2.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->llamafactory==0.9.4.dev0) (1.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->llamafactory==0.9.4.dev0) (4.9.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (1.3.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (3.13.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (1.0.9)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.4.dev0) (1.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->llamafactory==0.9.4.dev0) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->llamafactory==0.9.4.dev0) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->llamafactory==0.9.4.dev0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.4.dev0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.4.dev0) (2.19.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->llamafactory==0.9.4.dev0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->librosa->llamafactory==0.9.4.dev0) (2.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->llamafactory==0.9.4.dev0) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio<=5.45.0,>=4.38.0->llamafactory==0.9.4.dev0) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (6.7.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.4.dev0) (1.22.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->llamafactory==0.9.4.dev0) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.4.dev0) (0.1.2)
# Building wheels for collected packages: llamafactory
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.4.dev0-0.editable-py3-none-any.whl size=28938 sha256=32650c9bf6346f6e44d45658e850a78f2dc765ba3ae8b2f4df280d1db3ed74f6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yf1srufi/wheels/68/8b/5e/52f9888e6a91a2651260d603137c052b925af896da6e32a3f7
# Successfully built llamafactory
# Installing collected packages: llamafactory
#   Attempting uninstall: llamafactory
#     Found existing installation: llamafactory 0.9.4.dev0
#     Uninstalling llamafactory-0.9.4.dev0:
#       Successfully uninstalled llamafactory-0.9.4.dev0
# Successfully installed llamafactory-0.9.4.dev0

# %%
# !llamafactory-cli version
# Out:
# 2025-11-24 19:22:22.661215: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764012142.680589    3053 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764012142.686488    3053 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764012142.701374    3053 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764012142.701399    3053 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764012142.701404    3053 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764012142.701408    3053 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-24 19:22:22.706158: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ----------------------------------------------------------
# | Welcome to LLaMA Factory, version 0.9.4.dev0           |
# |                                                        |
# | Project page: https://github.com/hiyouga/LLaMA-Factory |
# ----------------------------------------------------------

# %% [markdown]
# ### Check GPU environment

# %%
import torch
try:
  assert torch.cuda.is_available() is True
except AssertionError:
  print("Please set up a GPU before using LLaMA Factory: https://medium.com/mlearning-ai/training-yolov4-on-google-colab-316f8fff99c6")

# %% [markdown]
# ## Update Identity Dataset

# %%
import json

# %cd /content/LLaMA-Factory/

NAME = "Llama-3"
AUTHOR = "LLaMA Factory"

with open("data/identity.json", "r", encoding="utf-8") as f:
  dataset = json.load(f)

for sample in dataset:
  sample["output"] = sample["output"].replace("{{"+ "name" + "}}", NAME).replace("{{"+ "author" + "}}", AUTHOR)

with open("data/identity.json", "w", encoding="utf-8") as f:
  json.dump(dataset, f, indent=2, ensure_ascii=False)
# Out:
# /content/LLaMA-Factory

# %% [markdown]
# ## Fine-tune model via LLaMA Board

# %%
# %cd /content/LLaMA-Factory/
# !GRADIO_SHARE=1 llamafactory-cli webui
# Out:
# /content/LLaMA-Factory
# 2025-11-24 19:17:33.618078: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764011853.650752    1790 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764011853.660985    1790 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764011853.685250    1790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764011853.685303    1790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764011853.685311    1790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764011853.685317    1790 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-24 19:17:33.692239: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/finalseg/__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")
# Visit http://ip:port for Web UI, e.g., http://127.0.0.1:7860
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://e0e03df492713f6ea6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3022, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/llamafactory-cli", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/content/LLaMA-Factory/src/llamafactory/cli.py", line 24, in main
#     launcher.launch()
#   File "/content/LLaMA-Factory/src/llamafactory/launcher.py", line 167, in launch
#     run_web_ui()
#   File "/content/LLaMA-Factory/src/llamafactory/webui/interface.py", line 97, in run_web_ui
#     create_ui().queue().launch(share=gradio_share, server_name=server_name, inbrowser=True)
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 2919, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/blocks.py", line 3026, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.12/dist-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/usr/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/usr/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Killing tunnel 0.0.0.0:7860 <> https://e0e03df492713f6ea6.gradio.live

# %% [markdown]
# ## Fine-tune model via Command Line
#
# It takes ~30min for training.

# %%
import json

args = dict(
  stage="sft",                                               # do supervised fine-tuning
  do_train=True,
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  dataset="identity,alpaca_en_demo",                         # use alpaca and identity datasets
  template="llama3",                                         # use llama3 prompt template
  finetuning_type="lora",                                    # use LoRA adapters to save memory
  lora_target="all",                                         # attach LoRA adapters to all linear layers
  output_dir="llama3_lora",                                  # the path to save LoRA adapters
  per_device_train_batch_size=2,                             # the micro batch size
  gradient_accumulation_steps=4,                             # the gradient accumulation steps
  lr_scheduler_type="cosine",                                # use cosine learning rate scheduler
  logging_steps=5,                                           # log every 5 steps
  warmup_ratio=0.1,                                          # use warmup scheduler
  save_steps=1000,                                           # save checkpoint every 1000 steps
  learning_rate=5e-5,                                        # the learning rate
  num_train_epochs=3.0,                                      # the epochs of training
  max_samples=500,                                           # use 500 examples in each dataset
  max_grad_norm=1.0,                                         # clip gradient norm to 1.0
  loraplus_lr_ratio=16.0,                                    # use LoRA+ algorithm with lambda=16.0
  fp16=True,                                                 # use float16 mixed precision training
  report_to="none",                                          # disable wandb logging
)

json.dump(args, open("train_llama3.json", "w", encoding="utf-8"), indent=2)

# %cd /content/LLaMA-Factory/

# !llamafactory-cli train train_llama3.json
# Out:
# /content/LLaMA-Factory
# 2025-11-24 19:24:39.974544: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764012279.994696    3632 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764012280.000575    3632 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764012280.016784    3632 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764012280.016812    3632 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764012280.016817    3632 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1764012280.016820    3632 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-11-24 19:24:40.021328: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO|2025-11-24 19:24:47] llamafactory.hparams.parser:468 >> Process rank: 0, world size: 1, device: cuda:0, distributed training: False, compute dtype: torch.float16
# tokenizer_config.json: 51.1kB [00:00, 122MB/s]
# tokenizer.json: 9.09MB [00:00, 131MB/s]
# special_tokens_map.json: 100% 345/345 [00:00<00:00, 2.11MB/s]
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:50,024 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:50,024 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:50,024 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:50,024 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:50,024 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:50,024 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2364] 2025-11-24 19:24:50,463 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 1.26kB [00:00, 6.59MB/s]
# [INFO|configuration_utils.py:765] 2025-11-24 19:24:51,907 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/config.json
# [INFO|configuration_utils.py:839] 2025-11-24 19:24:51,911 >> Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "dtype": "bfloat16",
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.57.1",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:52,398 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:52,398 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:52,398 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:52,398 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:52,398 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 19:24:52,398 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2364] 2025-11-24 19:24:52,834 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|2025-11-24 19:24:52] llamafactory.data.template:143 >> Add <|eom_id|> to stop words.
# [WARNING|2025-11-24 19:24:52] llamafactory.data.template:148 >> New tokens have been added, make sure `resize_vocab` is True.
# [INFO|2025-11-24 19:24:52] llamafactory.data.loader:143 >> Loading dataset identity.json...
# Generating train split: 91 examples [00:00, 4291.60 examples/s]
# Converting format of dataset: 100% 91/91 [00:00<00:00, 7923.80 examples/s]
# [INFO|2025-11-24 19:24:53] llamafactory.data.loader:143 >> Loading dataset alpaca_en_demo.json...
# Generating train split: 999 examples [00:00, 69885.25 examples/s]
# Converting format of dataset: 100% 500/500 [00:00<00:00, 13869.23 examples/s]
# Running tokenizer on dataset: 100% 591/591 [00:00<00:00, 1640.87 examples/s]
# training example:
# input_ids:
# [128000, 128006, 882, 128007, 271, 6151, 128009, 128006, 78191, 128007, 271, 9906, 0, 358, 1097, 445, 81101, 12, 18, 11, 459, 15592, 18328, 8040, 555, 445, 8921, 4940, 17367, 13, 2650, 649, 358, 7945, 499, 3432, 30, 128009]
# inputs:
# <|begin_of_text|><|start_header_id|>user<|end_header_id|>
#
# hi<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# Hello! I am Llama-3, an AI assistant developed by LLaMA Factory. How can I assist you today?<|eot_id|>
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 9906, 0, 358, 1097, 445, 81101, 12, 18, 11, 459, 15592, 18328, 8040, 555, 445, 8921, 4940, 17367, 13, 2650, 649, 358, 7945, 499, 3432, 30, 128009]
# labels:
# Hello! I am Llama-3, an AI assistant developed by LLaMA Factory. How can I assist you today?<|eot_id|>
# [INFO|configuration_utils.py:765] 2025-11-24 19:24:54,711 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/config.json
# [INFO|configuration_utils.py:839] 2025-11-24 19:24:54,712 >> Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "dtype": "bfloat16",
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.57.1",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|2025-11-24 19:24:54] llamafactory.model.model_utils.quantization:143 >> Loading ?-bit BITSANDBYTES-quantized model.
# [INFO|2025-11-24 19:24:54] llamafactory.model.model_utils.kv_cache:143 >> KV cache is disabled during training.
# [WARNING|logging.py:328] 2025-11-24 19:24:56,484 >> `torch_dtype` is deprecated! Use `dtype` instead!
# [INFO|quantization_config.py:508] 2025-11-24 19:24:56,484 >> Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# [INFO|auto.py:242] 2025-11-24 19:24:56,485 >>
# model.safetensors: 100% 5.70G/5.70G [00:39<00:00, 144MB/s]
# [INFO|modeling_utils.py:1172] 2025-11-24 19:25:41,668 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/model.safetensors
# [INFO|modeling_utils.py:2341] 2025-11-24 19:25:41,676 >> Instantiating LlamaForCausalLM model under default dtype torch.float16.
# [INFO|configuration_utils.py:986] 2025-11-24 19:25:41,678 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "pad_token_id": 128255,
#   "use_cache": false
# }
#
# generation_config.json: 100% 220/220 [00:00<00:00, 1.05MB/s]
# [INFO|configuration_utils.py:941] 2025-11-24 19:26:05,706 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/generation_config.json
# [INFO|configuration_utils.py:986] 2025-11-24 19:26:05,706 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128009
#   ],
#   "max_length": 8192,
#   "pad_token_id": 128255,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# [INFO|dynamic_module_utils.py:423] 2025-11-24 19:26:06,057 >> Could not locate the custom_generate/generate.py inside unsloth/llama-3-8b-Instruct-bnb-4bit.
# [INFO|2025-11-24 19:26:06] llamafactory.model.model_utils.checkpointing:143 >> Gradient checkpointing enabled.
# [INFO|2025-11-24 19:26:06] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2025-11-24 19:26:06] llamafactory.model.adapter:143 >> Upcasting trainable params to float32.
# [INFO|2025-11-24 19:26:06] llamafactory.model.adapter:143 >> Fine-tuning method: LoRA
# [INFO|2025-11-24 19:26:06] llamafactory.model.model_utils.misc:143 >> Found linear modules: o_proj,down_proj,up_proj,gate_proj,q_proj,k_proj,v_proj
# [INFO|2025-11-24 19:26:06] llamafactory.model.loader:143 >> trainable params: 20,971,520 || all params: 8,051,232,768 || trainable%: 0.2605
# [INFO|trainer.py:749] 2025-11-24 19:26:06,556 >> Using auto half precision backend
# [INFO|2025-11-24 19:26:07] llamafactory.train.trainer_utils:143 >> Using LoRA+ optimizer with loraplus lr ratio 16.00.
# [INFO|trainer.py:2519] 2025-11-24 19:26:07,040 >> ***** Running training *****
# [INFO|trainer.py:2520] 2025-11-24 19:26:07,040 >>   Num examples = 591
# [INFO|trainer.py:2521] 2025-11-24 19:26:07,040 >>   Num Epochs = 3
# [INFO|trainer.py:2522] 2025-11-24 19:26:07,040 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:2525] 2025-11-24 19:26:07,040 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:2526] 2025-11-24 19:26:07,040 >>   Gradient Accumulation steps = 4
# [INFO|trainer.py:2527] 2025-11-24 19:26:07,040 >>   Total optimization steps = 222
# [INFO|trainer.py:2528] 2025-11-24 19:26:07,044 >>   Number of trainable parameters = 20,971,520
# {'loss': 1.2661, 'grad_norm': 0.8007609248161316, 'learning_rate': 8.695652173913044e-06, 'epoch': 0.07}
# {'loss': 1.2326, 'grad_norm': 0.4438767433166504, 'learning_rate': 1.956521739130435e-05, 'epoch': 0.14}
# {'loss': 1.207, 'grad_norm': 0.6635714769363403, 'learning_rate': 3.0434782608695656e-05, 'epoch': 0.2}
# {'loss': 1.2355, 'grad_norm': 1.0918419361114502, 'learning_rate': 4.130434782608696e-05, 'epoch': 0.27}
# {'loss': 0.9942, 'grad_norm': 0.6350066661834717, 'learning_rate': 4.999688473794144e-05, 'epoch': 0.34}
# {'loss': 1.07, 'grad_norm': 0.7171353101730347, 'learning_rate': 4.9887932065027656e-05, 'epoch': 0.41}
# {'loss': 1.1393, 'grad_norm': 0.7998622059822083, 'learning_rate': 4.962399180850277e-05, 'epoch': 0.47}
# {'loss': 1.0549, 'grad_norm': 0.5134360790252686, 'learning_rate': 4.920670763496268e-05, 'epoch': 0.54}
# {'loss': 0.9872, 'grad_norm': 0.45713356137275696, 'learning_rate': 4.863867814784168e-05, 'epoch': 0.61}
# {'loss': 1.0752, 'grad_norm': 1.2872929573059082, 'learning_rate': 4.792344070481972e-05, 'epoch': 0.68}
# {'loss': 1.0264, 'grad_norm': 0.8582032322883606, 'learning_rate': 4.706544938921368e-05, 'epoch': 0.74}
# {'loss': 1.0538, 'grad_norm': 0.7802941203117371, 'learning_rate': 4.6070047272533765e-05, 'epoch': 0.81}
# {'loss': 1.1167, 'grad_norm': 0.5328021049499512, 'learning_rate': 4.4943433140937986e-05, 'epoch': 0.88}
# {'loss': 1.0688, 'grad_norm': 0.7700208425521851, 'learning_rate': 4.369262289279273e-05, 'epoch': 0.95}
# {'loss': 0.9301, 'grad_norm': 1.8046561479568481, 'learning_rate': 4.2325405847733294e-05, 'epoch': 1.01}
# {'loss': 0.7996, 'grad_norm': 1.6517738103866577, 'learning_rate': 4.085029623930597e-05, 'epoch': 1.08}
# {'loss': 0.6743, 'grad_norm': 0.9106818437576294, 'learning_rate': 3.927648019326737e-05, 'epoch': 1.15}
# {'loss': 0.729, 'grad_norm': 0.6346116065979004, 'learning_rate': 3.7613758521729436e-05, 'epoch': 1.22}
# {'loss': 0.6615, 'grad_norm': 0.419574111700058, 'learning_rate': 3.587248568939483e-05, 'epoch': 1.28}
# {'loss': 0.7908, 'grad_norm': 0.6578803062438965, 'learning_rate': 3.406350533196562e-05, 'epoch': 1.35}
# {'loss': 0.7458, 'grad_norm': 0.7138402462005615, 'learning_rate': 3.219808272827917e-05, 'epoch': 1.42}
# {'loss': 0.7111, 'grad_norm': 0.8451187610626221, 'learning_rate': 3.0287834646695477e-05, 'epoch': 1.49}
# {'loss': 0.635, 'grad_norm': 0.7180627584457397, 'learning_rate': 2.834465700261198e-05, 'epoch': 1.55}
# {'loss': 0.7024, 'grad_norm': 0.7828526496887207, 'learning_rate': 2.6380650777612705e-05, 'epoch': 1.62}
# {'loss': 0.6655, 'grad_norm': 0.7380252480506897, 'learning_rate': 2.4408046661584408e-05, 'epoch': 1.69}
# {'loss': 0.7343, 'grad_norm': 0.9274828433990479, 'learning_rate': 2.2439128887084673e-05, 'epoch': 1.76}
# {'loss': 0.7337, 'grad_norm': 1.2043604850769043, 'learning_rate': 2.0486158730277454e-05, 'epoch': 1.82}
# {'loss': 0.7214, 'grad_norm': 0.593544065952301, 'learning_rate': 1.856129815482759e-05, 'epoch': 1.89}
# {'loss': 0.658, 'grad_norm': 1.7256451845169067, 'learning_rate': 1.667653407425598e-05, 'epoch': 1.96}
# {'loss': 0.5564, 'grad_norm': 0.8047530651092529, 'learning_rate': 1.4843603704405279e-05, 'epoch': 2.03}
# {'loss': 0.438, 'grad_norm': 0.8664608597755432, 'learning_rate': 1.307392147087777e-05, 'epoch': 2.09}
# {'loss': 0.4024, 'grad_norm': 1.099026083946228, 'learning_rate': 1.1378507926623247e-05, 'epoch': 2.16}
# {'loss': 0.3853, 'grad_norm': 0.7396770715713501, 'learning_rate': 9.76792112233709e-06, 'epoch': 2.23}
# {'loss': 0.4344, 'grad_norm': 0.8365062475204468, 'learning_rate': 8.252190857053626e-06, 'epoch': 2.3}
# {'loss': 0.4409, 'grad_norm': 0.6821140050888062, 'learning_rate': 6.840756218384023e-06, 'epoch': 2.36}
# {'loss': 0.3994, 'grad_norm': 1.3465490341186523, 'learning_rate': 5.542406801361758e-06, 'epoch': 2.43}
# {'loss': 0.4229, 'grad_norm': 0.5970218181610107, 'learning_rate': 4.3652279719506e-06, 'epoch': 2.5}
# {'loss': 0.5373, 'grad_norm': 1.134852647781372, 'learning_rate': 3.316550516082137e-06, 'epoch': 2.57}
# {'loss': 0.3569, 'grad_norm': 0.8202747702598572, 'learning_rate': 2.402904987779414e-06, 'epoch': 2.64}
# {'loss': 0.2798, 'grad_norm': 0.9197311401367188, 'learning_rate': 1.6299810406600419e-06, 'epoch': 2.7}
# {'loss': 0.375, 'grad_norm': 1.0817598104476929, 'learning_rate': 1.0025919960785724e-06, 'epoch': 2.77}
# {'loss': 0.4872, 'grad_norm': 0.9277434945106506, 'learning_rate': 5.246448685571365e-07, 'epoch': 2.84}
# {'loss': 0.4774, 'grad_norm': 0.7372190356254578, 'learning_rate': 1.9911603516855338e-07, 'epoch': 2.91}
# {'loss': 0.4056, 'grad_norm': 0.736316442489624, 'learning_rate': 2.8032700388910814e-08, 'epoch': 2.97}
# 100% 222/222 [30:23<00:00,  7.42s/it][INFO|trainer.py:4309] 2025-11-24 19:56:30,521 >> Saving model checkpoint to llama3_lora/checkpoint-222
# [INFO|configuration_utils.py:765] 2025-11-24 19:56:31,122 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/config.json
# [INFO|configuration_utils.py:839] 2025-11-24 19:56:31,124 >> Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "dtype": "bfloat16",
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.57.1",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2421] 2025-11-24 19:56:31,341 >> chat template saved in llama3_lora/checkpoint-222/chat_template.jinja
# [INFO|tokenization_utils_base.py:2590] 2025-11-24 19:56:31,344 >> tokenizer config file saved in llama3_lora/checkpoint-222/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2599] 2025-11-24 19:56:31,344 >> Special tokens file saved in llama3_lora/checkpoint-222/special_tokens_map.json
# [INFO|trainer.py:2810] 2025-11-24 19:56:31,946 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 1824.9016, 'train_samples_per_second': 0.972, 'train_steps_per_second': 0.122, 'train_loss': 0.7425505231629621, 'epoch': 3.0}
# 100% 222/222 [30:24<00:00,  8.22s/it]
# [INFO|trainer.py:4309] 2025-11-24 19:56:31,948 >> Saving model checkpoint to llama3_lora
# [INFO|configuration_utils.py:765] 2025-11-24 19:56:32,478 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/config.json
# [INFO|configuration_utils.py:839] 2025-11-24 19:56:32,479 >> Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "dtype": "bfloat16",
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.57.1",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2421] 2025-11-24 19:56:32,646 >> chat template saved in llama3_lora/chat_template.jinja
# [INFO|tokenization_utils_base.py:2590] 2025-11-24 19:56:32,648 >> tokenizer config file saved in llama3_lora/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2599] 2025-11-24 19:56:32,649 >> Special tokens file saved in llama3_lora/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        3.0
#   total_flos               = 16222836GF
#   train_loss               =     0.7426
#   train_runtime            = 0:30:24.90
#   train_samples_per_second =      0.972
#   train_steps_per_second   =      0.122
# [INFO|modelcard.py:456] 2025-11-24 19:56:32,809 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}}

# %% [markdown]
# ## Infer the fine-tuned model

# %%
from llamafactory.chat import ChatModel
from llamafactory.extras.misc import torch_gc

# %cd /content/LLaMA-Factory/

args = dict(
  model_name_or_path="unsloth/llama-3-8b-Instruct-bnb-4bit", # use bnb-4bit-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="llama3_lora",                        # load the saved LoRA adapters
  template="llama3",                                         # same to the one in training
  finetuning_type="lora",                                    # same to the one in training
)
chat_model = ChatModel(args)

messages = []
print("Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application.")
while True:
  query = input("\nUser: ")
  if query.strip() == "exit":
    break
  if query.strip() == "clear":
    messages = []
    torch_gc()
    print("History has been removed.")
    continue

  messages.append({"role": "user", "content": query})
  print("Assistant: ", end="", flush=True)

  response = ""
  for new_text in chat_model.stream_chat(messages):
    print(new_text, end="", flush=True)
    response += new_text
  print()
  messages.append({"role": "assistant", "content": response})

torch_gc()
# Out:
# /content/LLaMA-Factory
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:06,170 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:06,171 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:06,172 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:06,173 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:06,173 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:06,174 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2364] 2025-11-24 20:01:06,590 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|configuration_utils.py:765] 2025-11-24 20:01:08,023 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/config.json
# [INFO|configuration_utils.py:839] 2025-11-24 20:01:08,028 >> Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "dtype": "bfloat16",
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.57.1",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:08,507 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:08,508 >> loading file tokenizer.model from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:08,508 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:08,509 >> loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:08,510 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2095] 2025-11-24 20:01:08,512 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2364] 2025-11-24 20:01:08,927 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|2025-11-24 20:01:08] llamafactory.data.template:143 >> Add <|eom_id|> to stop words.
# [WARNING|2025-11-24 20:01:08] llamafactory.data.template:148 >> New tokens have been added, make sure `resize_vocab` is True.
# [INFO|configuration_utils.py:765] 2025-11-24 20:01:09,191 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/config.json
# [INFO|configuration_utils.py:839] 2025-11-24 20:01:09,193 >> Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "dtype": "bfloat16",
#   "eos_token_id": 128009,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 8192,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128255,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.57.1",
#   "unsloth_version": "2024.9",
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# [WARNING|logging.py:328] 2025-11-24 20:01:09,193 >> `torch_dtype` is deprecated! Use `dtype` instead!
# [INFO|2025-11-24 20:01:09] llamafactory.model.model_utils.quantization:143 >> Loading ?-bit BITSANDBYTES-quantized model.
# [INFO|2025-11-24 20:01:09] llamafactory.model.model_utils.kv_cache:143 >> KV cache is enabled for faster generation.
# [WARNING|logging.py:328] 2025-11-24 20:01:11,686 >> `torch_dtype` is deprecated! Use `dtype` instead!
# [INFO|quantization_config.py:508] 2025-11-24 20:01:11,687 >> Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# [INFO|auto.py:242] 2025-11-24 20:01:11,691 >>
# [INFO|modeling_utils.py:1172] 2025-11-24 20:01:15,696 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/model.safetensors
# [INFO|modeling_utils.py:2341] 2025-11-24 20:01:15,702 >> Instantiating LlamaForCausalLM model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:986] 2025-11-24 20:01:15,704 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "eos_token_id": 128009,
#   "pad_token_id": 128255
# }
#
# [INFO|quantizer_bnb_4bit.py:141] 2025-11-24 20:01:15,871 >> target_dtype {target_dtype} is replaced by `CustomDtype.INT4` for 4-bit BnB quantization
# [INFO|configuration_utils.py:941] 2025-11-24 20:01:28,420 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--unsloth--llama-3-8b-Instruct-bnb-4bit/snapshots/fd5a4dc328319c1cfe9489eccfb9c6406bdfd469/generation_config.json
# [INFO|configuration_utils.py:986] 2025-11-24 20:01:28,421 >> Generate config GenerationConfig {
#   "bos_token_id": 128000,
#   "do_sample": true,
#   "eos_token_id": [
#     128001,
#     128009
#   ],
#   "max_length": 8192,
#   "pad_token_id": 128255,
#   "temperature": 0.6,
#   "top_p": 0.9
# }
#
# [INFO|dynamic_module_utils.py:423] 2025-11-24 20:01:28,656 >> Could not locate the custom_generate/generate.py inside unsloth/llama-3-8b-Instruct-bnb-4bit.
# [INFO|2025-11-24 20:01:28] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2025-11-24 20:01:29] llamafactory.model.adapter:143 >> Loaded adapter(s): llama3_lora
# [INFO|2025-11-24 20:01:29] llamafactory.model.loader:143 >> all params: 8,051,232,768
# Welcome to the CLI application, use `clear` to remove the history, use `exit` to exit the application.
#
# User: hello
# Assistant: Hello! I am Llama-3, an AI assistant developed by LLaMA Factory. How can I assist you today?

# %% [markdown]
# ## Merge the LoRA adapter and optionally upload model
#
# NOTE: the Colab free version has merely 12GB RAM, where merging LoRA of a 8B model needs at least 18GB RAM, thus you **cannot** perform it in the free version.

# %%
# !huggingface-cli login

# %%
import json

args = dict(
  model_name_or_path="meta-llama/Meta-Llama-3-8B-Instruct", # use official non-quantized Llama-3-8B-Instruct model
  adapter_name_or_path="llama3_lora",                       # load the saved LoRA adapters
  template="llama3",                                        # same to the one in training
  finetuning_type="lora",                                   # same to the one in training
  export_dir="llama3_lora_merged",                          # the path to save the merged model
  export_size=2,                                            # the file shard size (in GB) of the merged model
  export_device="cpu",                                      # the device used in export, can be chosen from `cpu` and `auto`
  # export_hub_model_id="your_id/your_model",               # the Hugging Face hub ID to upload model
)

json.dump(args, open("merge_llama3.json", "w", encoding="utf-8"), indent=2)

# %cd /content/LLaMA-Factory/

# !llamafactory-cli export merge_llama3.json
