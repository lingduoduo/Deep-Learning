# %% [markdown]
# # DeepSpeed Colab Demo
# Runtime → Change runtime type → GPU, then run cells below.

# %%
# !nvidia-smi

# %%
# !pip install -q torch transformers datasets accelerate deepspeed numpy

# %% [markdown]
# ## Upload zip, unzip, and enter repo

# %%
# After uploading deepspeed-zero-colab-demo.zip to Colab:
# !unzip -q -o deepspeed-zero-colab-demo.zip
# %cd deepspeed-zero-colab-demo

# %%
# !python train_baseline.py --model distilgpt2 --max_steps 20 --batch_size 2 --block_size 128

# %%
# !deepspeed --num_gpus=1 train_deepspeed.py --model distilgpt2 --max_steps 20 --batch_size 2 --block_size 128 --deepspeed_config ds_zero2_config.json

# %%
# !deepspeed --num_gpus=1 train_deepspeed.py --model distilgpt2 --max_steps 20 --batch_size 2 --block_size 128 --deepspeed_config ds_zero3_config.json
